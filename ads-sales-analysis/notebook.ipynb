# %% [markdown]
# # Ads Sales Analysis

# %% [markdown]
# - Nama: Bryan Herdianto
# - Email: bryan.herdianto17@gmail.com

# %% [markdown]
# ### Import library yang dibutuhkan

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import RepeatedKFold

# %% [markdown]
# ### Data Understanding

# %%
df = pd.read_csv('ads_sales.csv')
df
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 1             2              44.5                 39.3
# 2             3              17.2                 45.9
# 3             4             151.5                 41.3
# 4             5             180.8                 10.8
# ..          ...               ...                  ...
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 1                       45.1       10.4
# 2                       69.3        9.3
# 3                       58.5       18.5
# 4                       58.4       12.9
# ..                       ...        ...
# 195                     13.8        7.6
# 196                      8.1        9.7
# 197                      6.4       12.8
# 198                     66.2       25.5
# 199                      8.7       13.4
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               200 non-null    int64
#  1   TV Ad Budget ($)         200 non-null    float64
#  2   Radio Ad Budget ($)      200 non-null    float64
#  3   Newspaper Ad Budget ($)  200 non-null    float64
#  4   Sales ($)                200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# count  200.000000        200.000000           200.000000
# mean   100.500000        147.042500            23.264000
# std     57.879185         85.854236            14.846809
# min      1.000000          0.700000             0.000000
# 25%     50.750000         74.375000             9.975000
# 50%    100.500000        149.750000            22.900000
# 75%    150.250000        218.825000            36.525000
# max    200.000000        296.400000            49.600000
#
#        Newspaper Ad Budget ($)   Sales ($)
# count               200.000000  200.000000
# mean                 30.554000   14.022500
# std                  21.778621    5.217457
# min                   0.300000    1.600000
# 25%                  12.750000   10.375000
# 50%                  25.750000   12.900000
# 75%                  45.100000   17.400000
# max                 114.000000   27.000000

# %% [markdown]
# ### Data Preprocessing

# %%
# Drop unnecessary column and label
X = df.drop(['Unnamed: 0', 'Sales ($)'], axis=1)
X.head()
# Out:
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0             230.1                 37.8                     69.2
# 1              44.5                 39.3                     45.1
# 2              17.2                 45.9                     69.3
# 3             151.5                 41.3                     58.5
# 4             180.8                 10.8                     58.4

# %%
# Scale the data
mean = np.mean(X, axis=0)
std_dev = np.std(X, axis=0)
X_scaled = (X - mean) / std_dev
X_scaled
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0            0.969852             0.981522                 1.778945
# 1           -1.197376             1.082808                 0.669579
# 2           -1.516155             1.528463                 1.783549
# 3            0.052050             1.217855                 1.286405
# 4            0.394182            -0.841614                 1.281802
# ..                ...                  ...                      ...
# 195         -1.270941            -1.321031                -0.771217
# 196         -0.617035            -1.240003                -1.033598
# 197          0.349810            -0.942899                -1.111852
# 198          1.594565             1.265121                 1.640850
# 199          0.993206            -0.990165                -1.005979
#
# [200 rows x 3 columns]

# %%
X_train = X_scaled.loc[:159, :]
X_train.shape
# Out:
# (160, 3)

# %%
X_train
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0            0.969852             0.981522                 1.778945
# 1           -1.197376             1.082808                 0.669579
# 2           -1.516155             1.528463                 1.783549
# 3            0.052050             1.217855                 1.286405
# 4            0.394182            -0.841614                 1.281802
# ..                ...                  ...                      ...
# 155         -1.669122            -0.787595                -1.144075
# 156         -0.620538             1.366407                 0.918151
# 157          0.032199            -1.483087                -0.287883
# 158         -1.580378             0.920751                 0.674182
# 159         -0.179152            -0.328435                 0.186245
#
# [160 rows x 3 columns]

# %%
X_test = X_scaled.loc[160:200, :]
X_test.shape
# Out:
# (40, 3)

# %%
Y_train = df[['Sales ($)']].loc[:159, :]
Y_train.shape
# Out:
# (160, 1)

# %%
Y_train
# Out:
#      Sales ($)
# 0         22.1
# 1         10.4
# 2          9.3
# 3         18.5
# 4         12.9
# ..         ...
# 155        3.2
# 156       15.3
# 157       10.1
# 158        7.3
# 159       12.9
#
# [160 rows x 1 columns]

# %%
Y_test = df[['Sales ($)']].loc[160:200, :]
Y_test.shape
# Out:
# (40, 1)

# %% [markdown]
# ### Definitions
#
# - **z (Linear Combination):**
#   - $z$ is the linear combination of inputs and weights, plus a bias term. It represents the input to a neuron (before applying the activation function). For a neuron $i$ in layer $l$, it is computed as:
#     $$
#     z_i^{(l)} = \sum_{j} W_{ij}^{(l)} \cdot a_j^{(l-1)} + b_i^{(l)}
#     $$
#   - Here, $W_{ij}^{(l)}$ are the weights from neurons in the previous layer $(l-1)$ to the current layer $l$, and $b_i^{(l)}$ is the bias for the neuron $i$ in layer $l$.
#
# - **A (Activation):**
#   - $A$ is the activation output after applying an activation function $f(z)$ to the linear combination $z$. It represents the output of a neuron after activation. For a neuron $i$ in layer $l$:
#     $$
#     A_i^{(l)} = f(z_i^{(l)})
#     $$
#   - Common activation functions include ReLU, sigmoid, and tanh.
#
# - **W (Weights):**
#   - $W$ is the matrix of weights connecting neurons between two layers. Each element $W_{ij}$ represents the weight between the $j$th neuron in the previous layer and the $i$th neuron in the current layer.
#
# - **b (Bias):**
#   - $b$ is the bias term added to the linear combination $z$ before applying the activation function. It allows the model to fit the data better by adjusting the output independently of the input features.
#
# ### General Equation for Updating Parameters with Gradient Descent
#
# The parameters $W$ (weights) and $b$ (biases) in a neural network are updated using the gradient descent algorithm. The general update rule for each parameter $\theta$ (which could be $W$ or $b$) is:
#
# $$
# \theta = \theta - \alpha \cdot \frac{\partial J(\theta)}{\partial \theta}
# $$
#
# Where:
# - $\theta$ is the parameter being updated (either a weight $W$ or a bias $b$).
# - $\alpha$ is the learning rate, a hyperparameter that controls the size of the step taken in the direction of the gradient.
# - $\frac{\partial J(\theta)}{\partial \theta}$ is the gradient of the cost function $J(\theta)$ with respect to the parameter $\theta$.
#
# In a neural network, the update rules for weights and biases at layer $l$ are:
#
# $$
# W^{(l)} = W^{(l)} - \alpha \cdot \frac{\partial J}{\partial W^{(l)}}
# $$
#
# $$
# b^{(l)} = b^{(l)} - \alpha \cdot \frac{\partial J}{\partial b^{(l)}}
# $$
#
# This process is repeated iteratively to minimize the cost function and optimize the parameters.
#
# ### Gradient Functions and Derivations
#
# 1. **Gradient with respect to $W2$**:
#     ```python
#     dW2 = (2/m) * np.dot((Y_pred - Y_true).T, A1)
#     ```
#     - **Derivation**: The gradient of the cost function with respect to $W2$ is calculated as follows:
#       $$
#       \frac{\partial J}{\partial W2} = \frac{\partial J}{\partial Y_{\text{pred}}} \cdot \frac{\partial Y_{\text{pred}}}{\partial W2}
#       $$
#       $$
#       \frac{\partial J}{\partial W2} = \frac{2}{m} \cdot (Y_{\text{pred}} - Y_{\text{true}})^T \cdot A1
#       $$
#     - Here, $(Y_{\text{pred}} - Y_{\text{true}})$ represents the error term for the predictions. By taking the dot product with $A1$, the activations from the previous layer, we compute how the weights $W2$ should be adjusted to minimize the cost.
#
# 2. **Gradient with respect to $b2$**:
#     ```python
#     db2 = np.sum((2/m) * np.dot((Y_pred - Y_true).T, 1), axis=1, keepdims=True)
#     ```
#     - **Derivation**: The gradient of the cost function with respect to $b2$ is calculated as:
#       $$
#       \frac{\partial J}{\partial b2} = \frac{\partial J}{\partial Y_{\text{pred}}} \cdot \frac{\partial Y_{\text{pred}}}{\partial b2}
#       $$
#       $$
#       \frac{\partial J}{\partial b2} = \sum \left(\frac{2}{m} \cdot (Y_{\text{pred}} - Y_{\text{true}})\right)
#       $$
#     - Since $b2$ is a bias term that is added to all outputs equally, we sum the gradient contributions across all samples.
#
# 3. **Gradient with respect to $A1$**:
#     ```python
#     dA1 = (2/m) * np.dot((Y_pred - Y_true), W2)
#     ```
#     - **Derivation**: The gradient of the cost function with respect to the activations $A1$ from the hidden layer is given by:
#       $$
#       \frac{\partial J}{\partial A1} = \frac{\partial J}{\partial Y_{\text{pred}}} \cdot \frac{\partial Y_{\text{pred}}}{\partial A1}
#       $$
#       $$
#       \frac{\partial J}{\partial A1} = \frac{2}{m} \cdot (Y_{\text{pred}} - Y_{\text{true}}) \cdot W2
#       $$
#     - This backpropagates the error from the output layer to the hidden layer, scaling it by the weights $W2$.
#
# 4. **Gradient with respect to $z1$ (using ReLU derivative)**:
#     ```python
#     dz1 = dA1 * np.where(z1 > 0, 1, 0)
#     ```
#     - **Derivation**: The gradient of the cost function with respect to $z1$ is calculated by multiplying $dA1$ by the derivative of the ReLU activation function:
#       $$
#       \frac{\partial J}{\partial z1} = \frac{\partial J}{\partial A1} \cdot \frac{\partial A1}{\partial z1}
#       $$
#       $$
#       \frac{\partial J}{\partial z1} = dA1 \cdot f'(z1)
#       $$
#     - The derivative of ReLU $f'(z1)$ is 1 where $z1 > 0$, and 0 otherwise. This operation ensures that gradients only flow through the active neurons (where $z1 > 0$).
#
# 5. **Gradient with respect to $W1$**:
#     ```python
#     dW1 = np.dot(dz1.T, X)
#     ```
#     - **Derivation**: The gradient of the cost function with respect to $W1$ is:
#       $$
#       \frac{\partial J}{\partial W1} = \frac{\partial J}{\partial z1} \cdot \frac{\partial z1}{\partial W1}
#       $$
#       $$
#       \frac{\partial J}{\partial W1} = dz1^T \cdot X
#       $$
#     - This computes how the weights $W1$ connecting the input layer to the hidden layer should be adjusted to minimize the cost.
#
# 6. **Gradient with respect to $b1$**:
#     ```python
#     db1 = np.sum(np.dot(dz1.T, 1), axis=1, keepdims=True)
#     ```
#     - **Derivation**: The gradient of the cost function with respect to $b1$ is calculated by summing the gradient contributions across all samples:
#       $$
#       \frac{\partial J}{\partial b1} = \frac{\partial J}{\partial z1} \cdot \frac{\partial z1}{\partial b1}
#       $$
#       $$
#       \frac{\partial J}{\partial b1} = \sum dz1
#       $$
#     - This operation ensures that the bias is updated by the average influence of all input samples on the cost.

# %% [markdown]
# ### Loss Function
#
# The loss function used here is the **Mean Squared Error (MSE)**, which is commonly used for regression problems.
#
# The formula for MSE is:
# $$
# J = \frac{1}{m} \sum_{i=1}^{m} (Y_{\text{pred},i} - Y_{\text{true},i})^2
# $$
# Where:
# - $J$ is the cost (loss) function.
# - $m$ is the number of training examples.
# - $Y_{\text{pred},i}$ is the predicted value for the $i$-th training example.
# - $Y_{\text{true},i}$ is the actual value for the $i$-th training example.
#
# ### Derivative of the MSE Loss Function
#
# The derivative of the MSE loss function with respect to the predictions $Y_{\text{pred}}$ is:
#
# $$
# \frac{\partial J}{\partial Y_{\text{pred}}} = \frac{2}{m} \cdot (Y_{\text{pred}} - Y_{\text{true}})
# $$
#
# This derivative is used to compute the gradients for the backward propagation in the neural network. It represents the direction and magnitude of the change needed in the predicted values to reduce the overall loss.

# %%
# Function to initialize the weights and biases for the neural network
def inisiasi_awal(n):
    np.random.seed(10)  # Set seed for reproducibility
    W1 = np.random.randn(4, n) * 0.01  # Initialize W1 with small random values, shape (4, n)
    b1 = np.zeros((4, 1))  # Initialize b1 with zeros, shape (4, 1)
    W2 = np.random.randn(1, 4) * 0.01  # Initialize W2 with small random values, shape (1, 4)
    b2 = np.zeros((1, 1))  # Initialize b2 with zeros, shape (1, 1)
    return W1, W2, b1, b2  # Return initialized weights and biases

# Function to perform forward propagation
def forward_propagation(W1, W2, b1, b2, X, Y_true):
    # Layer input to hidden layer
    z1 = np.dot(W1, X.T) + b1  # Compute the linear combination for the hidden layer
    z1 = z1.T  # Transpose z1 to match the expected shape for further operations
    A1 = np.where(z1 > 0, z1, 0)  # Apply ReLU activation function
    assert A1.shape == (Y_true.shape[0], 4), ("Shape A1 salah! " + str(A1.shape))  # Ensure A1 has the correct shape
    
    # Hidden layer to output layer
    z2 = np.dot(W2, A1.T) + b2  # Compute the linear combination for the output layer
    Y_pred = z2.T  # Transpose Y_pred to match the shape of Y_true
    assert Y_pred.shape == Y_true.shape, ("Shape Y_pred salah! " + str(Y_pred.shape))  # Ensure Y_pred has the correct shape
    
    return z1, A1, z2, Y_pred  # Return the intermediate and final outputs

# Function to compute the cost (Mean Squared Error)
def cost_function(Y_pred, Y_true):
    if not isinstance(Y_true, np.ndarray):
        Y_true = Y_true.to_numpy()  # Convert Y_true to a NumPy array if it's not already
    
    loss = np.square((Y_pred - Y_true))  # Compute the squared differences
    cost = np.mean(loss)  # Compute the mean of the squared differences (MSE)
    return cost  # Return the cost

# Function to perform backpropagation to compute gradients
def back_propagation(X, W1, z1, A1, W2, z2, Y_pred, Y_true, m):
    # Output layer to hidden layer
    if not isinstance(Y_true, np.ndarray):
        Y_true = Y_true.to_numpy()  # Convert Y_true to a NumPy array if it's not already
    
    dW2 = (2/m) * np.dot((Y_pred - Y_true).T, A1)  # Compute gradient of the cost w.r.t W2
    db2 = np.sum((2/m) * np.dot((Y_pred - Y_true).T, 1), axis=1, keepdims=True)  # Compute gradient of the cost w.r.t b2
    assert dW2.shape == W2.shape, ("Shape dW2 salah! " + str(dW2.shape))  # Ensure dW2 has the correct shape
    
    # Hidden layer to input layer
    dA1 = (2/m) * np.dot((Y_pred - Y_true), W2)  # Compute gradient of the cost w.r.t A1
    dz1 = dA1 * np.where(z1 > 0, 1, 0)  # Compute gradient of the cost w.r.t z1 using ReLU derivative
    dW1 = np.dot(dz1.T, X)  # Compute gradient of the cost w.r.t W1
    db1 = np.sum(np.dot(dz1.T, 1), axis=1, keepdims=True)  # Compute gradient of the cost w.r.t b1
    assert dW1.shape == W1.shape, ("Shape dW1 salah! " + str(dW1.shape))  # Ensure dW1 has the correct shape
    
    return dW1, dW2, db1, db2  # Return the computed gradients

# Function to update parameters using the computed gradients
def update_parameter(learning_rate, W1, W2, b1, b2, dW1, dW2, db1, db2):
    W1 = W1 - learning_rate * dW1  # Update W1 using gradient descent
    b1 = b1 - learning_rate * db1  # Update b1 using gradient descent
    W2 = W2 - learning_rate * dW2  # Update W2 using gradient descent
    b2 = b2 - learning_rate * db2  # Update b2 using gradient descent
    return W1, W2, b1, b2  # Return the updated weights and biases

# %% [markdown]
# ### Vanilla / Batch Gradient Descent Optimization

# %%
# Assuming X_train and Y_train are already defined
m, n = X_train.shape
print("Jumlah sampel:", m, "dan jumlah Kolom:", n)

# Initialize parameters
W1_vanilla, W2_vanilla, b1_vanilla, b2_vanilla = inisiasi_awal(n)

# Training loop
for i in range(3000):
    # Forward propagation
    z1_vanilla, A1_vanilla, z2_vanilla, Y_pred_vanilla = forward_propagation(
        W1_vanilla, W2_vanilla, b1_vanilla, b2_vanilla, X_train, Y_train
    )
    
    # Compute cost
    cost_vanilla = cost_function(Y_pred_vanilla, Y_train)
    
    # Backward propagation
    dW1_vanilla, dW2_vanilla, db1_vanilla, db2_vanilla = back_propagation(
        X_train, W1_vanilla, z1_vanilla, A1_vanilla, W2_vanilla, z2_vanilla,
        Y_pred_vanilla, Y_train, m
    )
    
    # Update parameters
    W1_vanilla, W2_vanilla, b1_vanilla, b2_vanilla = update_parameter(
        0.005, W1_vanilla, W2_vanilla, b1_vanilla, b2_vanilla,
        dW1_vanilla, dW2_vanilla, db1_vanilla, db2_vanilla
    )
    
    # Print cost
    print("Cost ke-%d: %.4f" % (i + 1, cost_vanilla))
# Out:
# Cost ke-2956: 1.7738
# Cost ke-2957: 1.7739
# Cost ke-2958: 1.7738
# Cost ke-2959: 1.7739
# Cost ke-2960: 1.7738
# Cost ke-2961: 1.7739
# Cost ke-2962: 1.7739
# Cost ke-2963: 1.7738
# Cost ke-2964: 1.7739
# Cost ke-2965: 1.7738
# Cost ke-2966: 1.7740
# Cost ke-2967: 1.7738
# Cost ke-2968: 1.7739
# Cost ke-2969: 1.7739
# Cost ke-2970: 1.7738
# Cost ke-2971: 1.7739
# Cost ke-2972: 1.7738
# Cost ke-2973: 1.7740
# Cost ke-2974: 1.7738
# Cost ke-2975: 1.7739
# Cost ke-2976: 1.7739
# Cost ke-2977: 1.7738
# Cost ke-2978: 1.7739
# Cost ke-2979: 1.7738
# Cost ke-2980: 1.7740
# Cost ke-2981: 1.7738
# Cost ke-2982: 1.7739
# Cost ke-2983: 1.7739
# Cost ke-2984: 1.7738
# Cost ke-2985: 1.7739
# Cost ke-2986: 1.7738
# Cost ke-2987: 1.7740
# Cost ke-2988: 1.7738
# Cost ke-2989: 1.7739
# Cost ke-2990: 1.7738
# Cost ke-2991: 1.7738
# Cost ke-2992: 1.7739
# Cost ke-2993: 1.7738
# Cost ke-2994: 1.7739
# Cost ke-2995: 1.7738
# Cost ke-2996: 1.7739
# Cost ke-2997: 1.7738
# Cost ke-2998: 1.7739
# Cost ke-2999: 1.7739
# Cost ke-3000: 1.7738

# %%
# Forward propagation on the test set
_, _, _, Y_test_pred = forward_propagation(
    W1_vanilla, W2_vanilla, b1_vanilla, b2_vanilla, X_test, Y_test
)

print(Y_test_pred)
print(Y_test)

# Compute the cost on the test set
cost_test = cost_function(Y_test_pred, Y_test)

# Print the Mean Squared Error (MSE) on the test set
print("MSE pada testing:", cost_test)
# Out:
# [[12.82026298]
#  [12.47458535]
#  [13.73295107]
#  [17.33904342]
#  [10.64055604]
#  [13.87729589]
#  [ 9.09171198]
#  [12.89745947]
#  [16.70715742]
#  [17.31153404]
#  [ 8.327067  ]
#  [13.08154079]
#  [ 7.93349817]
#  [11.77967143]
#  [13.25118209]
#  [27.10430397]
#  [20.46758704]
#  [11.95995572]
#  [14.9445833 ]
#  [11.90473349]
#  [11.08015376]
#  [13.31135507]
#  [ 8.15918218]
#  [26.08200189]
#  [18.37090838]
#  [21.95381407]
#  [10.56137254]
#  [16.74346565]
#  [18.30206468]
#  [ 7.37894636]
#  [11.30168555]
#  [ 9.04477885]
#  [ 6.81126596]
#  [18.93505027]
#  [16.21850563]
#  [ 7.39463833]
#  [ 9.24509464]
#  [12.18324852]
#  [25.59201952]
#  [13.90177585]]
#      Sales ($)
# 160       14.4
# 161       13.3
# 162       14.9
# 163       18.0
# 164       11.9
# 165       11.9
# 166        8.0
# 167       12.2
# 168       17.1
# 169       15.0
# 170        8.4
# 171       14.5
# 172        7.6
# 173       11.7
# 174       11.5
# 175       27.0
# 176       20.2
# 177       11.7
# 178       11.8
# 179       12.6
# 180       10.5
# 181       12.2
# 182        8.7
# 183       26.2
# 184       17.6
# 185       22.6
# 186       10.3
# 187       17.3
# 188       15.9
# 189        6.7
# 190       10.8
# 191        9.9
# 192        5.9
# 193       19.6
# 194       17.3
# 195        7.6
# 196        9.7
# 197       12.8
# 198       25.5
# 199       13.4
# MSE pada testing: 1.1796190610861885

# %%
def forward_propagation_final(W1, W2, b1, b2, X):
    # Layer input ke hidden layer
    z1 = np.dot(W1, X.T) + b1
    z1 = z1.T
    A1 = np.where(z1 > 0, z1, 0)
    
    # Hidden layer ke output layer
    z2 = np.dot(W2, A1.T) + b2
    Y_pred = z2.T
    
    return z1, A1, z2, Y_pred

tv = float(input("What is your TV ad budget? "))
radio = float(input("What is your Radio ad budget? "))
newspaper = float(input("What is your Newspaper ad budget? "))

# group first via column
df_input = pd.DataFrame(
    {
        'TV Ad Budget ($)': [tv],
        'Radio Ad Budget ($)': [radio],
        'Newspaper Ad Budget ($)': [newspaper]
    }
)
print("\n")
print(df_input)

# scale the input
df_scaled = (df_input - mean) / std_dev
print("\n")
print(df_scaled)

# put into forward_propagation function
_, _, _, Y_test_pred = forward_propagation_final(
    W1_vanilla, W2_vanilla, b1_vanilla, b2_vanilla, df_scaled
)

# print result
print("\n")
print(Y_test_pred)
# Out:
# What is your TV ad budget?  39
# What is your Radio ad budget?  128
# What is your Newspaper ad budget?  48
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0              39.0                128.0                     48.0
#
#
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0         -1.261599             7.072148                 0.803071
#
#
# [[34.53979911]]

# %% [markdown]
# ### Mini-Batch Gradient Descent Optimization

# %%
# Initialize parameters
W1_mb, W2_mb, b1_mb, b2_mb = inisiasi_awal(n)

# Hyperparameters
learning_rate = 0.005
batch_size = 32
epochs = 2000

# Initialize variables to track the best weights and biases
best_W1_mb, best_W2_mb, best_b1_mb, best_b2_mb = W1_mb, W2_mb, b1_mb, b2_mb
best_cost = float('inf')

# Training loop
for epoch in range(epochs):
    # Shuffle data
    indices = np.arange(m)
    np.random.shuffle(indices)
    X_train_shuffled = X_train.iloc[indices]
    Y_train_shuffled = Y_train.iloc[indices]
    
    # Mini-batch processing
    for start in range(0, m, batch_size):
        end = min(start + batch_size, m)
        X_batch = X_train_shuffled.iloc[start:end]
        Y_batch = Y_train_shuffled.iloc[start:end]
        
        # Forward propagation
        z1_mb, A1_mb, z2_mb, Y_pred_mb = forward_propagation(
            W1_mb, W2_mb, b1_mb, b2_mb, X_batch, Y_batch
        )
        
        # Compute cost
        cost_mb = cost_function(Y_pred_mb, Y_batch)
        
        # Backward propagation
        dW1_mb, dW2_mb, db1_mb, db2_mb = back_propagation(
            X_batch, W1_mb, z1_mb, A1_mb, W2_mb, z2_mb,
            Y_pred_mb, Y_batch, len(X_batch)
        )
        
        # Update parameters
        W1_mb, W2_mb, b1_mb, b2_mb = update_parameter(
            learning_rate, W1_mb, W2_mb, b1_mb, b2_mb,
            dW1_mb, dW2_mb, db1_mb, db2_mb
        )
    
    # Print cost for the last mini-batch of the epoch
    print("Epoch %d: Last Mini-Batch Cost = %.4f" % (epoch + 1, cost_mb))
    
    # If the current epoch cost is the best (lowest), update the best weights and biases
    if cost_mb < best_cost:
        best_cost = cost_mb
        best_W1_mb, best_W2_mb, best_b1_mb, best_b2_mb = W1_mb, W2_mb, b1_mb, b2_mb
# Out:
# Epoch 1: Last Mini-Batch Cost = 233.8393
# Epoch 2: Last Mini-Batch Cost = 170.4956
# Epoch 3: Last Mini-Batch Cost = 183.7091
# Epoch 4: Last Mini-Batch Cost = 195.8025
# Epoch 5: Last Mini-Batch Cost = 135.9828
# Epoch 6: Last Mini-Batch Cost = 143.6402
# Epoch 7: Last Mini-Batch Cost = 97.8517
# Epoch 8: Last Mini-Batch Cost = 100.4681
# Epoch 9: Last Mini-Batch Cost = 84.6443
# Epoch 10: Last Mini-Batch Cost = 45.9516
# Epoch 11: Last Mini-Batch Cost = 21.6510
# Epoch 12: Last Mini-Batch Cost = 7.9025
# Epoch 13: Last Mini-Batch Cost = 4.3221
# Epoch 14: Last Mini-Batch Cost = 2.4894
# Epoch 15: Last Mini-Batch Cost = 4.2979
# Epoch 16: Last Mini-Batch Cost = 3.2847
# Epoch 17: Last Mini-Batch Cost = 4.2788
# Epoch 18: Last Mini-Batch Cost = 1.8078
# Epoch 19: Last Mini-Batch Cost = 2.0662
# Epoch 20: Last Mini-Batch Cost = 2.1664
# Epoch 21: Last Mini-Batch Cost = 3.9289
# Epoch 22: Last Mini-Batch Cost = 2.1170
# Epoch 23: Last Mini-Batch Cost = 2.0118
# Epoch 24: Last Mini-Batch Cost = 4.0601
# Epoch 25: Last Mini-Batch Cost = 4.5819
# Epoch 26: Last Mini-Batch Cost = 2.6677
# Epoch 27: Last Mini-Batch Cost = 2.2850
# Epoch 28: Last Mini-Batch Cost = 2.0868
# Epoch 29: Last Mini-Batch Cost = 2.5765
# Epoch 30: Last Mini-Batch Cost = 3.0083
# Epoch 31: Last Mini-Batch Cost = 4.6087
# Epoch 32: Last Mini-Batch Cost = 3.2378
# Epoch 33: Last Mini-Batch Cost = 1.7235
# Epoch 34: Last Mini-Batch Cost = 2.7507
# Epoch 35: Last Mini-Batch Cost = 4.5583
# Epoch 36: Last Mini-Batch Cost = 3.8993
# Epoch 37: Last Mini-Batch Cost = 4.3265
# Epoch 38: Last Mini-Batch Cost = 2.9374
# Epoch 39: Last Mini-Batch Cost = 2.9214
# Epoch 40: Last Mini-Batch Cost = 2.3078
# Epoch 41: Last Mini-Batch Cost = 1.7524
# Epoch 42: Last Mini-Batch Cost = 1.9137
# Epoch 43: Last Mini-Batch Cost = 3.6512
# Epoch 44: Last Mini-Batch Cost = 3.7097
# Epoch 45: Last Mini-Batch Cost = 2.1832
# Epoch 46: Last Mini-Batch Cost = 2.2886
# Epoch 47: Last Mini-Batch Cost = 2.8744
# Epoch 48: Last Mini-Batch Cost = 4.9238
# Epoch 49: Last Mini-Batch Cost = 3.7510
# Epoch 50: Last Mini-Batch Cost = 2.2928
# Epoch 51: Last Mini-Batch Cost = 2.6637
# Epoch 52: Last Mini-Batch Cost = 4.8288
# Epoch 53: Last Mini-Batch Cost = 2.4760
# Epoch 54: Last Mini-Batch Cost = 1.3425
# Epoch 55: Last Mini-Batch Cost = 2.0305
# Epoch 56: Last Mini-Batch Cost = 2.1782
# Epoch 57: Last Mini-Batch Cost = 2.2303
# Epoch 58: Last Mini-Batch Cost = 3.0001
# Epoch 59: Last Mini-Batch Cost = 1.7420
# Epoch 60: Last Mini-Batch Cost = 4.2550
# Epoch 61: Last Mini-Batch Cost = 1.8119
# Epoch 62: Last Mini-Batch Cost = 2.1801
# Epoch 63: Last Mini-Batch Cost = 2.4421
# Epoch 64: Last Mini-Batch Cost = 4.0186
# Epoch 65: Last Mini-Batch Cost = 1.5396
# Epoch 66: Last Mini-Batch Cost = 2.8495
# Epoch 67: Last Mini-Batch Cost = 3.1109
# Epoch 68: Last Mini-Batch Cost = 1.4253
# Epoch 69: Last Mini-Batch Cost = 2.6881
# Epoch 70: Last Mini-Batch Cost = 1.8613
# Epoch 71: Last Mini-Batch Cost = 1.5214
# Epoch 72: Last Mini-Batch Cost = 1.5297
# Epoch 73: Last Mini-Batch Cost = 1.9298
# Epoch 74: Last Mini-Batch Cost = 1.9220
# Epoch 75: Last Mini-Batch Cost = 2.0516
# Epoch 76: Last Mini-Batch Cost = 1.9132
# Epoch 77: Last Mini-Batch Cost = 4.0341
# Epoch 78: Last Mini-Batch Cost = 1.9608
# Epoch 79: Last Mini-Batch Cost = 3.7810
# Epoch 80: Last Mini-Batch Cost = 2.6191
# Epoch 81: Last Mini-Batch Cost = 1.2699
# Epoch 82: Last Mini-Batch Cost = 3.1191
# Epoch 83: Last Mini-Batch Cost = 3.8202
# Epoch 84: Last Mini-Batch Cost = 1.7616
# Epoch 85: Last Mini-Batch Cost = 1.6181
# Epoch 86: Last Mini-Batch Cost = 3.5270
# Epoch 87: Last Mini-Batch Cost = 1.8440
# Epoch 88: Last Mini-Batch Cost = 2.0538
# Epoch 89: Last Mini-Batch Cost = 1.2360
# Epoch 90: Last Mini-Batch Cost = 1.5896
# Epoch 91: Last Mini-Batch Cost = 1.2708
# Epoch 92: Last Mini-Batch Cost = 1.6981
# Epoch 93: Last Mini-Batch Cost = 1.8325
# Epoch 94: Last Mini-Batch Cost = 2.3579
# Epoch 95: Last Mini-Batch Cost = 2.5977
# Epoch 96: Last Mini-Batch Cost = 2.1757
# Epoch 97: Last Mini-Batch Cost = 2.8718
# Epoch 98: Last Mini-Batch Cost = 2.0574
# Epoch 99: Last Mini-Batch Cost = 2.1163
# Epoch 100: Last Mini-Batch Cost = 1.6990
# Epoch 101: Last Mini-Batch Cost = 1.8018
# Epoch 102: Last Mini-Batch Cost = 2.6825
# Epoch 103: Last Mini-Batch Cost = 1.5276
# Epoch 104: Last Mini-Batch Cost = 3.2867
# Epoch 105: Last Mini-Batch Cost = 2.7414
# Epoch 106: Last Mini-Batch Cost = 1.1932
# Epoch 107: Last Mini-Batch Cost = 1.4134
# Epoch 108: Last Mini-Batch Cost = 1.0651
# Epoch 109: Last Mini-Batch Cost = 1.9310
# Epoch 110: Last Mini-Batch Cost = 1.5811
# Epoch 111: Last Mini-Batch Cost = 1.1553
# Epoch 112: Last Mini-Batch Cost = 2.4523
# Epoch 113: Last Mini-Batch Cost = 1.0448
# Epoch 114: Last Mini-Batch Cost = 1.6270
# Epoch 115: Last Mini-Batch Cost = 1.7831
# Epoch 116: Last Mini-Batch Cost = 1.2834
# Epoch 117: Last Mini-Batch Cost = 1.4336
# Epoch 118: Last Mini-Batch Cost = 2.9321
# Epoch 119: Last Mini-Batch Cost = 1.5141
# Epoch 120: Last Mini-Batch Cost = 1.3455
# Epoch 121: Last Mini-Batch Cost = 2.0950
# Epoch 122: Last Mini-Batch Cost = 1.3166
# Epoch 123: Last Mini-Batch Cost = 1.3680
# Epoch 124: Last Mini-Batch Cost = 1.6443
# Epoch 125: Last Mini-Batch Cost = 1.5724
# Epoch 126: Last Mini-Batch Cost = 2.5745
# Epoch 127: Last Mini-Batch Cost = 1.1016
# Epoch 128: Last Mini-Batch Cost = 1.3364
# Epoch 129: Last Mini-Batch Cost = 1.7391
# Epoch 130: Last Mini-Batch Cost = 0.7841
# Epoch 131: Last Mini-Batch Cost = 3.8154
# Epoch 132: Last Mini-Batch Cost = 3.8963
# Epoch 133: Last Mini-Batch Cost = 0.8175
# Epoch 134: Last Mini-Batch Cost = 1.5184
# Epoch 135: Last Mini-Batch Cost = 2.0521
# Epoch 136: Last Mini-Batch Cost = 2.2598
# Epoch 137: Last Mini-Batch Cost = 1.6544
# Epoch 138: Last Mini-Batch Cost = 1.2123
# Epoch 139: Last Mini-Batch Cost = 2.7167
# Epoch 140: Last Mini-Batch Cost = 1.9753
# Epoch 141: Last Mini-Batch Cost = 1.7760
# Epoch 142: Last Mini-Batch Cost = 1.8213
# Epoch 143: Last Mini-Batch Cost = 2.1762
# Epoch 144: Last Mini-Batch Cost = 1.1641
# Epoch 145: Last Mini-Batch Cost = 2.1353
# Epoch 146: Last Mini-Batch Cost = 1.3575
# Epoch 147: Last Mini-Batch Cost = 0.8810
# Epoch 148: Last Mini-Batch Cost = 1.5871
# Epoch 149: Last Mini-Batch Cost = 1.1714
# Epoch 150: Last Mini-Batch Cost = 1.0394
# Epoch 151: Last Mini-Batch Cost = 1.8137
# Epoch 152: Last Mini-Batch Cost = 3.2535
# Epoch 153: Last Mini-Batch Cost = 2.0205
# Epoch 154: Last Mini-Batch Cost = 1.7833
# Epoch 155: Last Mini-Batch Cost = 1.0953
# Epoch 156: Last Mini-Batch Cost = 2.7291
# Epoch 157: Last Mini-Batch Cost = 1.9475
# Epoch 158: Last Mini-Batch Cost = 3.2985
# Epoch 159: Last Mini-Batch Cost = 1.1818
# Epoch 160: Last Mini-Batch Cost = 1.2501
# Epoch 161: Last Mini-Batch Cost = 1.0486
# Epoch 162: Last Mini-Batch Cost = 2.4681
# Epoch 163: Last Mini-Batch Cost = 3.3806
# Epoch 164: Last Mini-Batch Cost = 1.7360
# Epoch 165: Last Mini-Batch Cost = 1.4253
# Epoch 166: Last Mini-Batch Cost = 1.7852
# Epoch 167: Last Mini-Batch Cost = 2.1491
# Epoch 168: Last Mini-Batch Cost = 1.9590
# Epoch 169: Last Mini-Batch Cost = 1.2775
# Epoch 170: Last Mini-Batch Cost = 2.0945
# Epoch 171: Last Mini-Batch Cost = 2.6838
# Epoch 172: Last Mini-Batch Cost = 2.7669
# Epoch 173: Last Mini-Batch Cost = 1.2041
# Epoch 174: Last Mini-Batch Cost = 1.9730
# Epoch 175: Last Mini-Batch Cost = 1.1589
# Epoch 176: Last Mini-Batch Cost = 1.4119
# Epoch 177: Last Mini-Batch Cost = 1.7918
# Epoch 178: Last Mini-Batch Cost = 2.8426
# Epoch 179: Last Mini-Batch Cost = 1.3441
# Epoch 180: Last Mini-Batch Cost = 1.7385
# Epoch 181: Last Mini-Batch Cost = 2.2655
# Epoch 182: Last Mini-Batch Cost = 1.5408
# Epoch 183: Last Mini-Batch Cost = 1.3131
# Epoch 184: Last Mini-Batch Cost = 1.2418
# Epoch 185: Last Mini-Batch Cost = 2.8124
# Epoch 186: Last Mini-Batch Cost = 1.2849
# Epoch 187: Last Mini-Batch Cost = 1.6728
# Epoch 188: Last Mini-Batch Cost = 1.8608
# Epoch 189: Last Mini-Batch Cost = 3.5331
# Epoch 190: Last Mini-Batch Cost = 2.5600
# Epoch 191: Last Mini-Batch Cost = 1.7181
# Epoch 192: Last Mini-Batch Cost = 1.3600
# Epoch 193: Last Mini-Batch Cost = 2.7011
# Epoch 194: Last Mini-Batch Cost = 1.7570
# Epoch 195: Last Mini-Batch Cost = 2.1043
# Epoch 196: Last Mini-Batch Cost = 2.2544
# Epoch 197: Last Mini-Batch Cost = 1.2565
# Epoch 198: Last Mini-Batch Cost = 1.8864
# Epoch 199: Last Mini-Batch Cost = 1.4856
# Epoch 200: Last Mini-Batch Cost = 3.5442
# Epoch 201: Last Mini-Batch Cost = 1.1639
# Epoch 202: Last Mini-Batch Cost = 1.4508
# Epoch 203: Last Mini-Batch Cost = 1.4197
# Epoch 204: Last Mini-Batch Cost = 1.6241
# Epoch 205: Last Mini-Batch Cost = 1.3577
# Epoch 206: Last Mini-Batch Cost = 1.2611
# Epoch 207: Last Mini-Batch Cost = 1.0559
# Epoch 208: Last Mini-Batch Cost = 2.4322
# Epoch 209: Last Mini-Batch Cost = 1.8467
# Epoch 210: Last Mini-Batch Cost = 1.4705
# Epoch 211: Last Mini-Batch Cost = 1.4019
# Epoch 212: Last Mini-Batch Cost = 1.2326
# Epoch 213: Last Mini-Batch Cost = 0.8395
# Epoch 214: Last Mini-Batch Cost = 1.4142
# Epoch 215: Last Mini-Batch Cost = 1.7928
# Epoch 216: Last Mini-Batch Cost = 3.1308
# Epoch 217: Last Mini-Batch Cost = 3.2934
# Epoch 218: Last Mini-Batch Cost = 2.8262
# Epoch 219: Last Mini-Batch Cost = 1.4448
# Epoch 220: Last Mini-Batch Cost = 2.0301
# Epoch 221: Last Mini-Batch Cost = 1.0815
# Epoch 222: Last Mini-Batch Cost = 1.0916
# Epoch 223: Last Mini-Batch Cost = 2.2201
# Epoch 224: Last Mini-Batch Cost = 2.8827
# Epoch 225: Last Mini-Batch Cost = 1.3315
# Epoch 226: Last Mini-Batch Cost = 1.6965
# Epoch 227: Last Mini-Batch Cost = 2.8989
# Epoch 228: Last Mini-Batch Cost = 1.2316
# Epoch 229: Last Mini-Batch Cost = 2.9492
# Epoch 230: Last Mini-Batch Cost = 0.9514
# Epoch 231: Last Mini-Batch Cost = 1.1064
# Epoch 232: Last Mini-Batch Cost = 1.3398
# Epoch 233: Last Mini-Batch Cost = 2.5850
# Epoch 234: Last Mini-Batch Cost = 1.5918
# Epoch 235: Last Mini-Batch Cost = 1.4585
# Epoch 236: Last Mini-Batch Cost = 1.4635
# Epoch 237: Last Mini-Batch Cost = 2.9979
# Epoch 238: Last Mini-Batch Cost = 3.2509
# Epoch 239: Last Mini-Batch Cost = 1.8522
# Epoch 240: Last Mini-Batch Cost = 3.0359
# Epoch 241: Last Mini-Batch Cost = 1.8442
# Epoch 242: Last Mini-Batch Cost = 1.6047
# Epoch 243: Last Mini-Batch Cost = 1.8506
# Epoch 244: Last Mini-Batch Cost = 1.7010
# Epoch 245: Last Mini-Batch Cost = 1.7946
# Epoch 246: Last Mini-Batch Cost = 2.6926
# Epoch 247: Last Mini-Batch Cost = 2.7620
# Epoch 248: Last Mini-Batch Cost = 1.3322
# Epoch 249: Last Mini-Batch Cost = 2.8868
# Epoch 250: Last Mini-Batch Cost = 1.3978
# Epoch 251: Last Mini-Batch Cost = 1.1746
# Epoch 252: Last Mini-Batch Cost = 1.5778
# Epoch 253: Last Mini-Batch Cost = 1.1947
# Epoch 254: Last Mini-Batch Cost = 2.3095
# Epoch 255: Last Mini-Batch Cost = 1.9121
# Epoch 256: Last Mini-Batch Cost = 1.1278
# Epoch 257: Last Mini-Batch Cost = 1.3291
# Epoch 258: Last Mini-Batch Cost = 1.0967
# Epoch 259: Last Mini-Batch Cost = 1.2252
# Epoch 260: Last Mini-Batch Cost = 0.9402
# Epoch 261: Last Mini-Batch Cost = 1.5578
# Epoch 262: Last Mini-Batch Cost = 2.3955
# Epoch 263: Last Mini-Batch Cost = 1.3729
# Epoch 264: Last Mini-Batch Cost = 2.8967
# Epoch 265: Last Mini-Batch Cost = 1.6959
# Epoch 266: Last Mini-Batch Cost = 1.4780
# Epoch 267: Last Mini-Batch Cost = 1.2624
# Epoch 268: Last Mini-Batch Cost = 1.3053
# Epoch 269: Last Mini-Batch Cost = 1.3727
# Epoch 270: Last Mini-Batch Cost = 2.0407
# Epoch 271: Last Mini-Batch Cost = 1.8761
# Epoch 272: Last Mini-Batch Cost = 1.7488
# Epoch 273: Last Mini-Batch Cost = 1.6051
# Epoch 274: Last Mini-Batch Cost = 3.1922
# Epoch 275: Last Mini-Batch Cost = 1.3621
# Epoch 276: Last Mini-Batch Cost = 1.1130
# Epoch 277: Last Mini-Batch Cost = 1.5194
# Epoch 278: Last Mini-Batch Cost = 1.4988
# Epoch 279: Last Mini-Batch Cost = 2.0964
# Epoch 280: Last Mini-Batch Cost = 1.1766
# Epoch 281: Last Mini-Batch Cost = 1.3946
# Epoch 282: Last Mini-Batch Cost = 2.0681
# Epoch 283: Last Mini-Batch Cost = 1.8184
# Epoch 284: Last Mini-Batch Cost = 1.9656
# Epoch 285: Last Mini-Batch Cost = 1.4171
# Epoch 286: Last Mini-Batch Cost = 1.2063
# Epoch 287: Last Mini-Batch Cost = 1.6300
# Epoch 288: Last Mini-Batch Cost = 2.2047
# Epoch 289: Last Mini-Batch Cost = 1.2889
# Epoch 290: Last Mini-Batch Cost = 0.6087
# Epoch 291: Last Mini-Batch Cost = 1.7744
# Epoch 292: Last Mini-Batch Cost = 1.3651
# Epoch 293: Last Mini-Batch Cost = 2.3115
# Epoch 294: Last Mini-Batch Cost = 3.0051
# Epoch 295: Last Mini-Batch Cost = 1.1824
# Epoch 296: Last Mini-Batch Cost = 1.5582
# Epoch 297: Last Mini-Batch Cost = 2.8582
# Epoch 298: Last Mini-Batch Cost = 2.5891
# Epoch 299: Last Mini-Batch Cost = 1.8290
# Epoch 300: Last Mini-Batch Cost = 1.6535
# Epoch 301: Last Mini-Batch Cost = 1.7847
# Epoch 302: Last Mini-Batch Cost = 0.7226
# Epoch 303: Last Mini-Batch Cost = 2.7792
# Epoch 304: Last Mini-Batch Cost = 2.0956
# Epoch 305: Last Mini-Batch Cost = 1.1880
# Epoch 306: Last Mini-Batch Cost = 1.1606
# Epoch 307: Last Mini-Batch Cost = 3.8397
# Epoch 308: Last Mini-Batch Cost = 1.4374
# Epoch 309: Last Mini-Batch Cost = 3.4250
# Epoch 310: Last Mini-Batch Cost = 1.1809
# Epoch 311: Last Mini-Batch Cost = 1.9071
# Epoch 312: Last Mini-Batch Cost = 2.8835
# Epoch 313: Last Mini-Batch Cost = 2.0418
# Epoch 314: Last Mini-Batch Cost = 1.0490
# Epoch 315: Last Mini-Batch Cost = 1.2999
# Epoch 316: Last Mini-Batch Cost = 1.8612
# Epoch 317: Last Mini-Batch Cost = 1.2781
# Epoch 318: Last Mini-Batch Cost = 2.8469
# Epoch 319: Last Mini-Batch Cost = 2.1736
# Epoch 320: Last Mini-Batch Cost = 2.0163
# Epoch 321: Last Mini-Batch Cost = 1.6249
# Epoch 322: Last Mini-Batch Cost = 1.7535
# Epoch 323: Last Mini-Batch Cost = 1.5173
# Epoch 324: Last Mini-Batch Cost = 1.5275
# Epoch 325: Last Mini-Batch Cost = 2.3431
# Epoch 326: Last Mini-Batch Cost = 2.8927
# Epoch 327: Last Mini-Batch Cost = 1.0339
# Epoch 328: Last Mini-Batch Cost = 1.3659
# Epoch 329: Last Mini-Batch Cost = 1.2848
# Epoch 330: Last Mini-Batch Cost = 0.8524
# Epoch 331: Last Mini-Batch Cost = 1.1309
# Epoch 332: Last Mini-Batch Cost = 2.3927
# Epoch 333: Last Mini-Batch Cost = 2.7109
# Epoch 334: Last Mini-Batch Cost = 3.5857
# Epoch 335: Last Mini-Batch Cost = 1.1677
# Epoch 336: Last Mini-Batch Cost = 1.8253
# Epoch 337: Last Mini-Batch Cost = 3.1280
# Epoch 338: Last Mini-Batch Cost = 1.7017
# Epoch 339: Last Mini-Batch Cost = 1.1097
# Epoch 340: Last Mini-Batch Cost = 1.6610
# Epoch 341: Last Mini-Batch Cost = 1.5030
# Epoch 342: Last Mini-Batch Cost = 1.0650
# Epoch 343: Last Mini-Batch Cost = 1.2172
# Epoch 344: Last Mini-Batch Cost = 3.4403
# Epoch 345: Last Mini-Batch Cost = 1.2868
# Epoch 346: Last Mini-Batch Cost = 2.3949
# Epoch 347: Last Mini-Batch Cost = 1.1300
# Epoch 348: Last Mini-Batch Cost = 1.5679
# Epoch 349: Last Mini-Batch Cost = 1.3621
# Epoch 350: Last Mini-Batch Cost = 1.1056
# Epoch 351: Last Mini-Batch Cost = 1.5691
# Epoch 352: Last Mini-Batch Cost = 2.0339
# Epoch 353: Last Mini-Batch Cost = 3.1660
# Epoch 354: Last Mini-Batch Cost = 0.9832
# Epoch 355: Last Mini-Batch Cost = 1.3133
# Epoch 356: Last Mini-Batch Cost = 1.2069
# Epoch 357: Last Mini-Batch Cost = 1.2355
# Epoch 358: Last Mini-Batch Cost = 1.6070
# Epoch 359: Last Mini-Batch Cost = 3.6052
# Epoch 360: Last Mini-Batch Cost = 3.0745
# Epoch 361: Last Mini-Batch Cost = 3.0522
# Epoch 362: Last Mini-Batch Cost = 1.6443
# Epoch 363: Last Mini-Batch Cost = 1.4574
# Epoch 364: Last Mini-Batch Cost = 1.3838
# Epoch 365: Last Mini-Batch Cost = 2.2751
# Epoch 366: Last Mini-Batch Cost = 1.6699
# Epoch 367: Last Mini-Batch Cost = 1.9528
# Epoch 368: Last Mini-Batch Cost = 3.0115
# Epoch 369: Last Mini-Batch Cost = 2.0501
# Epoch 370: Last Mini-Batch Cost = 1.4096
# Epoch 371: Last Mini-Batch Cost = 1.5910
# Epoch 372: Last Mini-Batch Cost = 0.9063
# Epoch 373: Last Mini-Batch Cost = 2.4834
# Epoch 374: Last Mini-Batch Cost = 0.9851
# Epoch 375: Last Mini-Batch Cost = 1.8958
# Epoch 376: Last Mini-Batch Cost = 2.6088
# Epoch 377: Last Mini-Batch Cost = 1.3000
# Epoch 378: Last Mini-Batch Cost = 1.4614
# Epoch 379: Last Mini-Batch Cost = 3.5643
# Epoch 380: Last Mini-Batch Cost = 1.7714
# Epoch 381: Last Mini-Batch Cost = 1.2730
# Epoch 382: Last Mini-Batch Cost = 3.4484
# Epoch 383: Last Mini-Batch Cost = 0.9465
# Epoch 384: Last Mini-Batch Cost = 1.3228
# Epoch 385: Last Mini-Batch Cost = 2.3452
# Epoch 386: Last Mini-Batch Cost = 2.6578
# Epoch 387: Last Mini-Batch Cost = 1.1172
# Epoch 388: Last Mini-Batch Cost = 1.6606
# Epoch 389: Last Mini-Batch Cost = 2.7791
# Epoch 390: Last Mini-Batch Cost = 1.6305
# Epoch 391: Last Mini-Batch Cost = 2.5460
# Epoch 392: Last Mini-Batch Cost = 2.7594
# Epoch 393: Last Mini-Batch Cost = 0.8436
# Epoch 394: Last Mini-Batch Cost = 1.1848
# Epoch 395: Last Mini-Batch Cost = 1.7917
# Epoch 396: Last Mini-Batch Cost = 0.5700
# Epoch 397: Last Mini-Batch Cost = 1.1530
# Epoch 398: Last Mini-Batch Cost = 1.9403
# Epoch 399: Last Mini-Batch Cost = 2.9672
# Epoch 400: Last Mini-Batch Cost = 0.7859
# Epoch 401: Last Mini-Batch Cost = 1.1440
# Epoch 402: Last Mini-Batch Cost = 2.2242
# Epoch 403: Last Mini-Batch Cost = 1.7195
# Epoch 404: Last Mini-Batch Cost = 1.5123
# Epoch 405: Last Mini-Batch Cost = 1.7117
# Epoch 406: Last Mini-Batch Cost = 3.7579
# Epoch 407: Last Mini-Batch Cost = 1.7063
# Epoch 408: Last Mini-Batch Cost = 1.5739
# Epoch 409: Last Mini-Batch Cost = 1.1187
# Epoch 410: Last Mini-Batch Cost = 1.0641
# Epoch 411: Last Mini-Batch Cost = 1.1708
# Epoch 412: Last Mini-Batch Cost = 2.1161
# Epoch 413: Last Mini-Batch Cost = 1.3865
# Epoch 414: Last Mini-Batch Cost = 1.2806
# Epoch 415: Last Mini-Batch Cost = 3.3890
# Epoch 416: Last Mini-Batch Cost = 1.1102
# Epoch 417: Last Mini-Batch Cost = 1.6130
# Epoch 418: Last Mini-Batch Cost = 1.4079
# Epoch 419: Last Mini-Batch Cost = 2.8350
# Epoch 420: Last Mini-Batch Cost = 1.9262
# Epoch 421: Last Mini-Batch Cost = 2.1068
# Epoch 422: Last Mini-Batch Cost = 1.5031
# Epoch 423: Last Mini-Batch Cost = 0.8399
# Epoch 424: Last Mini-Batch Cost = 1.7246
# Epoch 425: Last Mini-Batch Cost = 0.7609
# Epoch 426: Last Mini-Batch Cost = 1.5079
# Epoch 427: Last Mini-Batch Cost = 1.6596
# Epoch 428: Last Mini-Batch Cost = 2.8900
# Epoch 429: Last Mini-Batch Cost = 1.9848
# Epoch 430: Last Mini-Batch Cost = 2.5540
# Epoch 431: Last Mini-Batch Cost = 1.7049
# Epoch 432: Last Mini-Batch Cost = 1.2984
# Epoch 433: Last Mini-Batch Cost = 1.6424
# Epoch 434: Last Mini-Batch Cost = 0.7771
# Epoch 435: Last Mini-Batch Cost = 1.5882
# Epoch 436: Last Mini-Batch Cost = 1.3473
# Epoch 437: Last Mini-Batch Cost = 1.5950
# Epoch 438: Last Mini-Batch Cost = 1.7462
# Epoch 439: Last Mini-Batch Cost = 1.4831
# Epoch 440: Last Mini-Batch Cost = 2.5102
# Epoch 441: Last Mini-Batch Cost = 1.6514
# Epoch 442: Last Mini-Batch Cost = 1.6653
# Epoch 443: Last Mini-Batch Cost = 0.9285
# Epoch 444: Last Mini-Batch Cost = 2.6527
# Epoch 445: Last Mini-Batch Cost = 3.2474
# Epoch 446: Last Mini-Batch Cost = 1.7348
# Epoch 447: Last Mini-Batch Cost = 1.8084
# Epoch 448: Last Mini-Batch Cost = 1.5922
# Epoch 449: Last Mini-Batch Cost = 3.1242
# Epoch 450: Last Mini-Batch Cost = 1.6724
# Epoch 451: Last Mini-Batch Cost = 1.4337
# Epoch 452: Last Mini-Batch Cost = 3.6565
# Epoch 453: Last Mini-Batch Cost = 2.4293
# Epoch 454: Last Mini-Batch Cost = 1.6849
# Epoch 455: Last Mini-Batch Cost = 1.7106
# Epoch 456: Last Mini-Batch Cost = 1.2805
# Epoch 457: Last Mini-Batch Cost = 1.5080
# Epoch 458: Last Mini-Batch Cost = 1.0492
# Epoch 459: Last Mini-Batch Cost = 1.0881
# Epoch 460: Last Mini-Batch Cost = 1.2845
# Epoch 461: Last Mini-Batch Cost = 1.6793
# Epoch 462: Last Mini-Batch Cost = 2.7281
# Epoch 463: Last Mini-Batch Cost = 1.6958
# Epoch 464: Last Mini-Batch Cost = 1.0331
# Epoch 465: Last Mini-Batch Cost = 2.5048
# Epoch 466: Last Mini-Batch Cost = 1.1402
# Epoch 467: Last Mini-Batch Cost = 1.8205
# Epoch 468: Last Mini-Batch Cost = 1.8153
# Epoch 469: Last Mini-Batch Cost = 1.9265
# Epoch 470: Last Mini-Batch Cost = 3.1469
# Epoch 471: Last Mini-Batch Cost = 1.9997
# Epoch 472: Last Mini-Batch Cost = 1.3666
# Epoch 473: Last Mini-Batch Cost = 1.0957
# Epoch 474: Last Mini-Batch Cost = 1.2618
# Epoch 475: Last Mini-Batch Cost = 1.7407
# Epoch 476: Last Mini-Batch Cost = 2.5982
# Epoch 477: Last Mini-Batch Cost = 1.9449
# Epoch 478: Last Mini-Batch Cost = 1.2370
# Epoch 479: Last Mini-Batch Cost = 1.2909
# Epoch 480: Last Mini-Batch Cost = 3.3958
# Epoch 481: Last Mini-Batch Cost = 1.6022
# Epoch 482: Last Mini-Batch Cost = 1.3446
# Epoch 483: Last Mini-Batch Cost = 1.3781
# Epoch 484: Last Mini-Batch Cost = 1.1403
# Epoch 485: Last Mini-Batch Cost = 2.5649
# Epoch 486: Last Mini-Batch Cost = 1.7948
# Epoch 487: Last Mini-Batch Cost = 1.1821
# Epoch 488: Last Mini-Batch Cost = 2.1032
# Epoch 489: Last Mini-Batch Cost = 3.6841
# Epoch 490: Last Mini-Batch Cost = 0.9465
# Epoch 491: Last Mini-Batch Cost = 0.9759
# Epoch 492: Last Mini-Batch Cost = 3.1351
# Epoch 493: Last Mini-Batch Cost = 1.4643
# Epoch 494: Last Mini-Batch Cost = 1.3072
# Epoch 495: Last Mini-Batch Cost = 0.9586
# Epoch 496: Last Mini-Batch Cost = 1.8720
# Epoch 497: Last Mini-Batch Cost = 1.4622
# Epoch 498: Last Mini-Batch Cost = 1.6084
# Epoch 499: Last Mini-Batch Cost = 2.6345
# Epoch 500: Last Mini-Batch Cost = 1.2841
# Epoch 501: Last Mini-Batch Cost = 1.2805
# Epoch 502: Last Mini-Batch Cost = 1.4169
# Epoch 503: Last Mini-Batch Cost = 1.4407
# Epoch 504: Last Mini-Batch Cost = 1.2846
# Epoch 505: Last Mini-Batch Cost = 1.8457
# Epoch 506: Last Mini-Batch Cost = 2.3799
# Epoch 507: Last Mini-Batch Cost = 1.3864
# Epoch 508: Last Mini-Batch Cost = 2.6049
# Epoch 509: Last Mini-Batch Cost = 1.5627
# Epoch 510: Last Mini-Batch Cost = 1.9933
# Epoch 511: Last Mini-Batch Cost = 2.0804
# Epoch 512: Last Mini-Batch Cost = 3.2217
# Epoch 513: Last Mini-Batch Cost = 1.5961
# Epoch 514: Last Mini-Batch Cost = 2.1454
# Epoch 515: Last Mini-Batch Cost = 1.1985
# Epoch 516: Last Mini-Batch Cost = 1.3998
# Epoch 517: Last Mini-Batch Cost = 1.5849
# Epoch 518: Last Mini-Batch Cost = 1.4304
# Epoch 519: Last Mini-Batch Cost = 3.2739
# Epoch 520: Last Mini-Batch Cost = 1.3606
# Epoch 521: Last Mini-Batch Cost = 3.1835
# Epoch 522: Last Mini-Batch Cost = 1.3194
# Epoch 523: Last Mini-Batch Cost = 2.7241
# Epoch 524: Last Mini-Batch Cost = 1.4150
# Epoch 525: Last Mini-Batch Cost = 1.4462
# Epoch 526: Last Mini-Batch Cost = 3.8554
# Epoch 527: Last Mini-Batch Cost = 1.6624
# Epoch 528: Last Mini-Batch Cost = 1.1696
# Epoch 529: Last Mini-Batch Cost = 1.4602
# Epoch 530: Last Mini-Batch Cost = 1.2068
# Epoch 531: Last Mini-Batch Cost = 1.3209
# Epoch 532: Last Mini-Batch Cost = 1.1724
# Epoch 533: Last Mini-Batch Cost = 1.1165
# Epoch 534: Last Mini-Batch Cost = 1.2646
# Epoch 535: Last Mini-Batch Cost = 1.8495
# Epoch 536: Last Mini-Batch Cost = 2.8798
# Epoch 537: Last Mini-Batch Cost = 1.3567
# Epoch 538: Last Mini-Batch Cost = 1.8891
# Epoch 539: Last Mini-Batch Cost = 1.4301
# Epoch 540: Last Mini-Batch Cost = 3.4385
# Epoch 541: Last Mini-Batch Cost = 1.2090
# Epoch 542: Last Mini-Batch Cost = 3.7381
# Epoch 543: Last Mini-Batch Cost = 1.3477
# Epoch 544: Last Mini-Batch Cost = 1.9438
# Epoch 545: Last Mini-Batch Cost = 3.6927
# Epoch 546: Last Mini-Batch Cost = 1.8391
# Epoch 547: Last Mini-Batch Cost = 1.1054
# Epoch 548: Last Mini-Batch Cost = 1.5907
# Epoch 549: Last Mini-Batch Cost = 2.0354
# Epoch 550: Last Mini-Batch Cost = 1.2709
# Epoch 551: Last Mini-Batch Cost = 2.0999
# Epoch 552: Last Mini-Batch Cost = 3.6902
# Epoch 553: Last Mini-Batch Cost = 1.8360
# Epoch 554: Last Mini-Batch Cost = 1.2702
# Epoch 555: Last Mini-Batch Cost = 1.5008
# Epoch 556: Last Mini-Batch Cost = 1.5088
# Epoch 557: Last Mini-Batch Cost = 1.4396
# Epoch 558: Last Mini-Batch Cost = 1.7273
# Epoch 559: Last Mini-Batch Cost = 1.4363
# Epoch 560: Last Mini-Batch Cost = 1.6280
# Epoch 561: Last Mini-Batch Cost = 2.5792
# Epoch 562: Last Mini-Batch Cost = 1.6111
# Epoch 563: Last Mini-Batch Cost = 1.5286
# Epoch 564: Last Mini-Batch Cost = 2.7861
# Epoch 565: Last Mini-Batch Cost = 1.7944
# Epoch 566: Last Mini-Batch Cost = 1.3548
# Epoch 567: Last Mini-Batch Cost = 1.2569
# Epoch 568: Last Mini-Batch Cost = 3.1473
# Epoch 569: Last Mini-Batch Cost = 1.5907
# Epoch 570: Last Mini-Batch Cost = 1.6039
# Epoch 571: Last Mini-Batch Cost = 3.4250
# Epoch 572: Last Mini-Batch Cost = 2.9707
# Epoch 573: Last Mini-Batch Cost = 2.7878
# Epoch 574: Last Mini-Batch Cost = 2.6135
# Epoch 575: Last Mini-Batch Cost = 3.0364
# Epoch 576: Last Mini-Batch Cost = 1.2610
# Epoch 577: Last Mini-Batch Cost = 3.4136
# Epoch 578: Last Mini-Batch Cost = 1.4090
# Epoch 579: Last Mini-Batch Cost = 1.0283
# Epoch 580: Last Mini-Batch Cost = 1.8598
# Epoch 581: Last Mini-Batch Cost = 1.7078
# Epoch 582: Last Mini-Batch Cost = 1.6689
# Epoch 583: Last Mini-Batch Cost = 1.7862
# Epoch 584: Last Mini-Batch Cost = 1.9358
# Epoch 585: Last Mini-Batch Cost = 1.1891
# Epoch 586: Last Mini-Batch Cost = 1.2127
# Epoch 587: Last Mini-Batch Cost = 1.4789
# Epoch 588: Last Mini-Batch Cost = 1.6159
# Epoch 589: Last Mini-Batch Cost = 0.7834
# Epoch 590: Last Mini-Batch Cost = 2.1130
# Epoch 591: Last Mini-Batch Cost = 1.7577
# Epoch 592: Last Mini-Batch Cost = 0.9626
# Epoch 593: Last Mini-Batch Cost = 2.0170
# Epoch 594: Last Mini-Batch Cost = 2.6612
# Epoch 595: Last Mini-Batch Cost = 2.8112
# Epoch 596: Last Mini-Batch Cost = 1.5305
# Epoch 597: Last Mini-Batch Cost = 1.9751
# Epoch 598: Last Mini-Batch Cost = 1.0774
# Epoch 599: Last Mini-Batch Cost = 1.4430
# Epoch 600: Last Mini-Batch Cost = 1.3846
# Epoch 601: Last Mini-Batch Cost = 2.3553
# Epoch 602: Last Mini-Batch Cost = 1.7421
# Epoch 603: Last Mini-Batch Cost = 3.4598
# Epoch 604: Last Mini-Batch Cost = 1.2838
# Epoch 605: Last Mini-Batch Cost = 1.1915
# Epoch 606: Last Mini-Batch Cost = 2.1048
# Epoch 607: Last Mini-Batch Cost = 2.0458
# Epoch 608: Last Mini-Batch Cost = 1.4148
# Epoch 609: Last Mini-Batch Cost = 1.6168
# Epoch 610: Last Mini-Batch Cost = 3.2486
# Epoch 611: Last Mini-Batch Cost = 1.3961
# Epoch 612: Last Mini-Batch Cost = 1.2468
# Epoch 613: Last Mini-Batch Cost = 1.1688
# Epoch 614: Last Mini-Batch Cost = 2.3486
# Epoch 615: Last Mini-Batch Cost = 3.1800
# Epoch 616: Last Mini-Batch Cost = 1.6415
# Epoch 617: Last Mini-Batch Cost = 2.4498
# Epoch 618: Last Mini-Batch Cost = 3.0824
# Epoch 619: Last Mini-Batch Cost = 1.3979
# Epoch 620: Last Mini-Batch Cost = 2.2866
# Epoch 621: Last Mini-Batch Cost = 0.8925
# Epoch 622: Last Mini-Batch Cost = 1.8225
# Epoch 623: Last Mini-Batch Cost = 1.5910
# Epoch 624: Last Mini-Batch Cost = 2.1127
# Epoch 625: Last Mini-Batch Cost = 2.8252
# Epoch 626: Last Mini-Batch Cost = 1.4729
# Epoch 627: Last Mini-Batch Cost = 1.2246
# Epoch 628: Last Mini-Batch Cost = 1.0136
# Epoch 629: Last Mini-Batch Cost = 2.2244
# Epoch 630: Last Mini-Batch Cost = 1.4933
# Epoch 631: Last Mini-Batch Cost = 2.1934
# Epoch 632: Last Mini-Batch Cost = 1.1458
# Epoch 633: Last Mini-Batch Cost = 1.5345
# Epoch 634: Last Mini-Batch Cost = 1.8766
# Epoch 635: Last Mini-Batch Cost = 1.1543
# Epoch 636: Last Mini-Batch Cost = 2.0312
# Epoch 637: Last Mini-Batch Cost = 2.0314
# Epoch 638: Last Mini-Batch Cost = 2.1666
# Epoch 639: Last Mini-Batch Cost = 2.6489
# Epoch 640: Last Mini-Batch Cost = 1.7781
# Epoch 641: Last Mini-Batch Cost = 1.5096
# Epoch 642: Last Mini-Batch Cost = 2.3186
# Epoch 643: Last Mini-Batch Cost = 1.3624
# Epoch 644: Last Mini-Batch Cost = 2.1389
# Epoch 645: Last Mini-Batch Cost = 2.7281
# Epoch 646: Last Mini-Batch Cost = 1.6158
# Epoch 647: Last Mini-Batch Cost = 1.7799
# Epoch 648: Last Mini-Batch Cost = 1.3970
# Epoch 649: Last Mini-Batch Cost = 2.1888
# Epoch 650: Last Mini-Batch Cost = 1.7605
# Epoch 651: Last Mini-Batch Cost = 1.2289
# Epoch 652: Last Mini-Batch Cost = 1.4894
# Epoch 653: Last Mini-Batch Cost = 2.2605
# Epoch 654: Last Mini-Batch Cost = 2.3923
# Epoch 655: Last Mini-Batch Cost = 1.7437
# Epoch 656: Last Mini-Batch Cost = 1.9210
# Epoch 657: Last Mini-Batch Cost = 2.0165
# Epoch 658: Last Mini-Batch Cost = 1.1872
# Epoch 659: Last Mini-Batch Cost = 3.5360
# Epoch 660: Last Mini-Batch Cost = 1.1154
# Epoch 661: Last Mini-Batch Cost = 2.2384
# Epoch 662: Last Mini-Batch Cost = 0.9450
# Epoch 663: Last Mini-Batch Cost = 2.9246
# Epoch 664: Last Mini-Batch Cost = 1.0992
# Epoch 665: Last Mini-Batch Cost = 2.0081
# Epoch 666: Last Mini-Batch Cost = 1.0584
# Epoch 667: Last Mini-Batch Cost = 1.6352
# Epoch 668: Last Mini-Batch Cost = 1.6933
# Epoch 669: Last Mini-Batch Cost = 1.3985
# Epoch 670: Last Mini-Batch Cost = 1.2690
# Epoch 671: Last Mini-Batch Cost = 1.7150
# Epoch 672: Last Mini-Batch Cost = 1.7484
# Epoch 673: Last Mini-Batch Cost = 3.0917
# Epoch 674: Last Mini-Batch Cost = 2.9739
# Epoch 675: Last Mini-Batch Cost = 1.2994
# Epoch 676: Last Mini-Batch Cost = 1.2378
# Epoch 677: Last Mini-Batch Cost = 0.8389
# Epoch 678: Last Mini-Batch Cost = 2.0478
# Epoch 679: Last Mini-Batch Cost = 1.9856
# Epoch 680: Last Mini-Batch Cost = 1.1653
# Epoch 681: Last Mini-Batch Cost = 1.1271
# Epoch 682: Last Mini-Batch Cost = 3.0615
# Epoch 683: Last Mini-Batch Cost = 1.9863
# Epoch 684: Last Mini-Batch Cost = 2.4582
# Epoch 685: Last Mini-Batch Cost = 1.5111
# Epoch 686: Last Mini-Batch Cost = 2.6826
# Epoch 687: Last Mini-Batch Cost = 1.7123
# Epoch 688: Last Mini-Batch Cost = 1.2792
# Epoch 689: Last Mini-Batch Cost = 1.0105
# Epoch 690: Last Mini-Batch Cost = 1.7925
# Epoch 691: Last Mini-Batch Cost = 1.1315
# Epoch 692: Last Mini-Batch Cost = 2.4423
# Epoch 693: Last Mini-Batch Cost = 1.4542
# Epoch 694: Last Mini-Batch Cost = 1.5566
# Epoch 695: Last Mini-Batch Cost = 1.2757
# Epoch 696: Last Mini-Batch Cost = 2.0218
# Epoch 697: Last Mini-Batch Cost = 1.2756
# Epoch 698: Last Mini-Batch Cost = 2.3298
# Epoch 699: Last Mini-Batch Cost = 1.6057
# Epoch 700: Last Mini-Batch Cost = 3.0693
# Epoch 701: Last Mini-Batch Cost = 1.0009
# Epoch 702: Last Mini-Batch Cost = 1.1738
# Epoch 703: Last Mini-Batch Cost = 1.6617
# Epoch 704: Last Mini-Batch Cost = 1.8337
# Epoch 705: Last Mini-Batch Cost = 1.4251
# Epoch 706: Last Mini-Batch Cost = 3.5901
# Epoch 707: Last Mini-Batch Cost = 0.5647
# Epoch 708: Last Mini-Batch Cost = 1.4749
# Epoch 709: Last Mini-Batch Cost = 1.3207
# Epoch 710: Last Mini-Batch Cost = 1.5359
# Epoch 711: Last Mini-Batch Cost = 2.7109
# Epoch 712: Last Mini-Batch Cost = 2.3436
# Epoch 713: Last Mini-Batch Cost = 2.7977
# Epoch 714: Last Mini-Batch Cost = 3.4580
# Epoch 715: Last Mini-Batch Cost = 0.9246
# Epoch 716: Last Mini-Batch Cost = 0.9199
# Epoch 717: Last Mini-Batch Cost = 1.1162
# Epoch 718: Last Mini-Batch Cost = 1.4182
# Epoch 719: Last Mini-Batch Cost = 0.7586
# Epoch 720: Last Mini-Batch Cost = 1.9276
# Epoch 721: Last Mini-Batch Cost = 1.3643
# Epoch 722: Last Mini-Batch Cost = 1.2088
# Epoch 723: Last Mini-Batch Cost = 1.3941
# Epoch 724: Last Mini-Batch Cost = 1.7897
# Epoch 725: Last Mini-Batch Cost = 1.2825
# Epoch 726: Last Mini-Batch Cost = 1.4507
# Epoch 727: Last Mini-Batch Cost = 1.3487
# Epoch 728: Last Mini-Batch Cost = 2.1466
# Epoch 729: Last Mini-Batch Cost = 2.6690
# Epoch 730: Last Mini-Batch Cost = 0.7818
# Epoch 731: Last Mini-Batch Cost = 2.0368
# Epoch 732: Last Mini-Batch Cost = 1.4676
# Epoch 733: Last Mini-Batch Cost = 1.8283
# Epoch 734: Last Mini-Batch Cost = 3.3880
# Epoch 735: Last Mini-Batch Cost = 1.4208
# Epoch 736: Last Mini-Batch Cost = 3.6717
# Epoch 737: Last Mini-Batch Cost = 1.3251
# Epoch 738: Last Mini-Batch Cost = 0.9402
# Epoch 739: Last Mini-Batch Cost = 1.0532
# Epoch 740: Last Mini-Batch Cost = 1.2735
# Epoch 741: Last Mini-Batch Cost = 1.3716
# Epoch 742: Last Mini-Batch Cost = 3.3282
# Epoch 743: Last Mini-Batch Cost = 1.4619
# Epoch 744: Last Mini-Batch Cost = 1.8475
# Epoch 745: Last Mini-Batch Cost = 1.1264
# Epoch 746: Last Mini-Batch Cost = 1.1253
# Epoch 747: Last Mini-Batch Cost = 2.4937
# Epoch 748: Last Mini-Batch Cost = 1.1511
# Epoch 749: Last Mini-Batch Cost = 2.4219
# Epoch 750: Last Mini-Batch Cost = 1.6816
# Epoch 751: Last Mini-Batch Cost = 1.1162
# Epoch 752: Last Mini-Batch Cost = 1.6446
# Epoch 753: Last Mini-Batch Cost = 1.3814
# Epoch 754: Last Mini-Batch Cost = 1.7276
# Epoch 755: Last Mini-Batch Cost = 1.4092
# Epoch 756: Last Mini-Batch Cost = 1.8658
# Epoch 757: Last Mini-Batch Cost = 1.6847
# Epoch 758: Last Mini-Batch Cost = 1.0708
# Epoch 759: Last Mini-Batch Cost = 2.2141
# Epoch 760: Last Mini-Batch Cost = 0.9936
# Epoch 761: Last Mini-Batch Cost = 1.7430
# Epoch 762: Last Mini-Batch Cost = 2.1194
# Epoch 763: Last Mini-Batch Cost = 1.1425
# Epoch 764: Last Mini-Batch Cost = 2.2534
# Epoch 765: Last Mini-Batch Cost = 1.1009
# Epoch 766: Last Mini-Batch Cost = 2.5478
# Epoch 767: Last Mini-Batch Cost = 1.8397
# Epoch 768: Last Mini-Batch Cost = 1.5128
# Epoch 769: Last Mini-Batch Cost = 1.5793
# Epoch 770: Last Mini-Batch Cost = 2.3474
# Epoch 771: Last Mini-Batch Cost = 1.1683
# Epoch 772: Last Mini-Batch Cost = 2.8221
# Epoch 773: Last Mini-Batch Cost = 1.1694
# Epoch 774: Last Mini-Batch Cost = 2.9818
# Epoch 775: Last Mini-Batch Cost = 0.7374
# Epoch 776: Last Mini-Batch Cost = 1.4384
# Epoch 777: Last Mini-Batch Cost = 1.4169
# Epoch 778: Last Mini-Batch Cost = 1.5782
# Epoch 779: Last Mini-Batch Cost = 1.2914
# Epoch 780: Last Mini-Batch Cost = 2.0773
# Epoch 781: Last Mini-Batch Cost = 1.6090
# Epoch 782: Last Mini-Batch Cost = 1.3998
# Epoch 783: Last Mini-Batch Cost = 1.1929
# Epoch 784: Last Mini-Batch Cost = 1.2529
# Epoch 785: Last Mini-Batch Cost = 1.2770
# Epoch 786: Last Mini-Batch Cost = 2.7187
# Epoch 787: Last Mini-Batch Cost = 1.2938
# Epoch 788: Last Mini-Batch Cost = 3.0198
# Epoch 789: Last Mini-Batch Cost = 1.8632
# Epoch 790: Last Mini-Batch Cost = 1.7794
# Epoch 791: Last Mini-Batch Cost = 1.4133
# Epoch 792: Last Mini-Batch Cost = 1.6614
# Epoch 793: Last Mini-Batch Cost = 2.1154
# Epoch 794: Last Mini-Batch Cost = 1.0053
# Epoch 795: Last Mini-Batch Cost = 1.4428
# Epoch 796: Last Mini-Batch Cost = 1.4224
# Epoch 797: Last Mini-Batch Cost = 2.8359
# Epoch 798: Last Mini-Batch Cost = 3.3611
# Epoch 799: Last Mini-Batch Cost = 1.6337
# Epoch 800: Last Mini-Batch Cost = 1.8684
# Epoch 801: Last Mini-Batch Cost = 1.5083
# Epoch 802: Last Mini-Batch Cost = 1.1878
# Epoch 803: Last Mini-Batch Cost = 1.5959
# Epoch 804: Last Mini-Batch Cost = 0.9813
# Epoch 805: Last Mini-Batch Cost = 1.2269
# Epoch 806: Last Mini-Batch Cost = 1.4696
# Epoch 807: Last Mini-Batch Cost = 1.2950
# Epoch 808: Last Mini-Batch Cost = 1.3040
# Epoch 809: Last Mini-Batch Cost = 1.5372
# Epoch 810: Last Mini-Batch Cost = 1.3984
# Epoch 811: Last Mini-Batch Cost = 1.3840
# Epoch 812: Last Mini-Batch Cost = 1.4215
# Epoch 813: Last Mini-Batch Cost = 2.5248
# Epoch 814: Last Mini-Batch Cost = 1.4420
# Epoch 815: Last Mini-Batch Cost = 2.2770
# Epoch 816: Last Mini-Batch Cost = 2.2937
# Epoch 817: Last Mini-Batch Cost = 1.9946
# Epoch 818: Last Mini-Batch Cost = 2.7455
# Epoch 819: Last Mini-Batch Cost = 2.4393
# Epoch 820: Last Mini-Batch Cost = 1.5035
# Epoch 821: Last Mini-Batch Cost = 1.1411
# Epoch 822: Last Mini-Batch Cost = 1.3122
# Epoch 823: Last Mini-Batch Cost = 1.9667
# Epoch 824: Last Mini-Batch Cost = 1.9183
# Epoch 825: Last Mini-Batch Cost = 2.0420
# Epoch 826: Last Mini-Batch Cost = 1.7160
# Epoch 827: Last Mini-Batch Cost = 1.9613
# Epoch 828: Last Mini-Batch Cost = 0.8969
# Epoch 829: Last Mini-Batch Cost = 1.7400
# Epoch 830: Last Mini-Batch Cost = 1.6435
# Epoch 831: Last Mini-Batch Cost = 1.5883
# Epoch 832: Last Mini-Batch Cost = 2.8297
# Epoch 833: Last Mini-Batch Cost = 1.9996
# Epoch 834: Last Mini-Batch Cost = 1.6409
# Epoch 835: Last Mini-Batch Cost = 1.2613
# Epoch 836: Last Mini-Batch Cost = 1.1256
# Epoch 837: Last Mini-Batch Cost = 1.4208
# Epoch 838: Last Mini-Batch Cost = 1.6334
# Epoch 839: Last Mini-Batch Cost = 2.2229
# Epoch 840: Last Mini-Batch Cost = 1.3624
# Epoch 841: Last Mini-Batch Cost = 1.2403
# Epoch 842: Last Mini-Batch Cost = 1.3117
# Epoch 843: Last Mini-Batch Cost = 1.5901
# Epoch 844: Last Mini-Batch Cost = 3.8010
# Epoch 845: Last Mini-Batch Cost = 1.9039
# Epoch 846: Last Mini-Batch Cost = 1.4456
# Epoch 847: Last Mini-Batch Cost = 1.4058
# Epoch 848: Last Mini-Batch Cost = 1.4917
# Epoch 849: Last Mini-Batch Cost = 2.0619
# Epoch 850: Last Mini-Batch Cost = 2.4273
# Epoch 851: Last Mini-Batch Cost = 1.0990
# Epoch 852: Last Mini-Batch Cost = 2.2715
# Epoch 853: Last Mini-Batch Cost = 1.9196
# Epoch 854: Last Mini-Batch Cost = 1.0357
# Epoch 855: Last Mini-Batch Cost = 3.2848
# Epoch 856: Last Mini-Batch Cost = 1.2940
# Epoch 857: Last Mini-Batch Cost = 1.1250
# Epoch 858: Last Mini-Batch Cost = 1.6412
# Epoch 859: Last Mini-Batch Cost = 1.2395
# Epoch 860: Last Mini-Batch Cost = 1.6098
# Epoch 861: Last Mini-Batch Cost = 3.5718
# Epoch 862: Last Mini-Batch Cost = 1.5061
# Epoch 863: Last Mini-Batch Cost = 1.5633
# Epoch 864: Last Mini-Batch Cost = 2.1821
# Epoch 865: Last Mini-Batch Cost = 1.7978
# Epoch 866: Last Mini-Batch Cost = 1.2019
# Epoch 867: Last Mini-Batch Cost = 1.8399
# Epoch 868: Last Mini-Batch Cost = 1.9317
# Epoch 869: Last Mini-Batch Cost = 2.0661
# Epoch 870: Last Mini-Batch Cost = 3.8603
# Epoch 871: Last Mini-Batch Cost = 1.1139
# Epoch 872: Last Mini-Batch Cost = 3.2292
# Epoch 873: Last Mini-Batch Cost = 2.3268
# Epoch 874: Last Mini-Batch Cost = 1.7275
# Epoch 875: Last Mini-Batch Cost = 1.2412
# Epoch 876: Last Mini-Batch Cost = 2.5099
# Epoch 877: Last Mini-Batch Cost = 1.1699
# Epoch 878: Last Mini-Batch Cost = 2.2312
# Epoch 879: Last Mini-Batch Cost = 1.1545
# Epoch 880: Last Mini-Batch Cost = 1.1132
# Epoch 881: Last Mini-Batch Cost = 1.2719
# Epoch 882: Last Mini-Batch Cost = 2.8021
# Epoch 883: Last Mini-Batch Cost = 1.6256
# Epoch 884: Last Mini-Batch Cost = 1.0920
# Epoch 885: Last Mini-Batch Cost = 1.5029
# Epoch 886: Last Mini-Batch Cost = 0.9027
# Epoch 887: Last Mini-Batch Cost = 3.0674
# Epoch 888: Last Mini-Batch Cost = 2.1354
# Epoch 889: Last Mini-Batch Cost = 1.6052
# Epoch 890: Last Mini-Batch Cost = 1.3270
# Epoch 891: Last Mini-Batch Cost = 1.8459
# Epoch 892: Last Mini-Batch Cost = 1.4914
# Epoch 893: Last Mini-Batch Cost = 3.3163
# Epoch 894: Last Mini-Batch Cost = 1.1421
# Epoch 895: Last Mini-Batch Cost = 3.7870
# Epoch 896: Last Mini-Batch Cost = 1.3391
# Epoch 897: Last Mini-Batch Cost = 3.4874
# Epoch 898: Last Mini-Batch Cost = 2.1562
# Epoch 899: Last Mini-Batch Cost = 2.8710
# Epoch 900: Last Mini-Batch Cost = 2.5108
# Epoch 901: Last Mini-Batch Cost = 3.2972
# Epoch 902: Last Mini-Batch Cost = 1.1584
# Epoch 903: Last Mini-Batch Cost = 1.5077
# Epoch 904: Last Mini-Batch Cost = 0.9033
# Epoch 905: Last Mini-Batch Cost = 1.6307
# Epoch 906: Last Mini-Batch Cost = 1.4624
# Epoch 907: Last Mini-Batch Cost = 3.3036
# Epoch 908: Last Mini-Batch Cost = 1.1698
# Epoch 909: Last Mini-Batch Cost = 1.2878
# Epoch 910: Last Mini-Batch Cost = 1.5062
# Epoch 911: Last Mini-Batch Cost = 2.3678
# Epoch 912: Last Mini-Batch Cost = 1.2217
# Epoch 913: Last Mini-Batch Cost = 1.7624
# Epoch 914: Last Mini-Batch Cost = 1.3265
# Epoch 915: Last Mini-Batch Cost = 2.4517
# Epoch 916: Last Mini-Batch Cost = 1.1393
# Epoch 917: Last Mini-Batch Cost = 1.3125
# Epoch 918: Last Mini-Batch Cost = 2.5142
# Epoch 919: Last Mini-Batch Cost = 1.4753
# Epoch 920: Last Mini-Batch Cost = 3.4878
# Epoch 921: Last Mini-Batch Cost = 2.2128
# Epoch 922: Last Mini-Batch Cost = 3.4241
# Epoch 923: Last Mini-Batch Cost = 2.8330
# Epoch 924: Last Mini-Batch Cost = 1.7341
# Epoch 925: Last Mini-Batch Cost = 3.8707
# Epoch 926: Last Mini-Batch Cost = 1.1077
# Epoch 927: Last Mini-Batch Cost = 1.9522
# Epoch 928: Last Mini-Batch Cost = 3.9341
# Epoch 929: Last Mini-Batch Cost = 1.7177
# Epoch 930: Last Mini-Batch Cost = 1.1201
# Epoch 931: Last Mini-Batch Cost = 2.0319
# Epoch 932: Last Mini-Batch Cost = 1.1669
# Epoch 933: Last Mini-Batch Cost = 1.4123
# Epoch 934: Last Mini-Batch Cost = 1.1042
# Epoch 935: Last Mini-Batch Cost = 1.3138
# Epoch 936: Last Mini-Batch Cost = 2.0885
# Epoch 937: Last Mini-Batch Cost = 3.1567
# Epoch 938: Last Mini-Batch Cost = 1.8005
# Epoch 939: Last Mini-Batch Cost = 1.1127
# Epoch 940: Last Mini-Batch Cost = 0.9068
# Epoch 941: Last Mini-Batch Cost = 1.3041
# Epoch 942: Last Mini-Batch Cost = 2.3441
# Epoch 943: Last Mini-Batch Cost = 1.7456
# Epoch 944: Last Mini-Batch Cost = 1.2406
# Epoch 945: Last Mini-Batch Cost = 3.6054
# Epoch 946: Last Mini-Batch Cost = 2.1345
# Epoch 947: Last Mini-Batch Cost = 1.9348
# Epoch 948: Last Mini-Batch Cost = 1.6574
# Epoch 949: Last Mini-Batch Cost = 1.3863
# Epoch 950: Last Mini-Batch Cost = 1.0982
# Epoch 951: Last Mini-Batch Cost = 1.9416
# Epoch 952: Last Mini-Batch Cost = 3.2074
# Epoch 953: Last Mini-Batch Cost = 0.9367
# Epoch 954: Last Mini-Batch Cost = 1.5061
# Epoch 955: Last Mini-Batch Cost = 1.5212
# Epoch 956: Last Mini-Batch Cost = 0.8504
# Epoch 957: Last Mini-Batch Cost = 1.8006
# Epoch 958: Last Mini-Batch Cost = 1.1349
# Epoch 959: Last Mini-Batch Cost = 1.3640
# Epoch 960: Last Mini-Batch Cost = 3.5581
# Epoch 961: Last Mini-Batch Cost = 1.8603
# Epoch 962: Last Mini-Batch Cost = 3.2848
# Epoch 963: Last Mini-Batch Cost = 1.8994
# Epoch 964: Last Mini-Batch Cost = 3.0744
# Epoch 965: Last Mini-Batch Cost = 1.7531
# Epoch 966: Last Mini-Batch Cost = 1.1643
# Epoch 967: Last Mini-Batch Cost = 1.7104
# Epoch 968: Last Mini-Batch Cost = 1.1722
# Epoch 969: Last Mini-Batch Cost = 2.1551
# Epoch 970: Last Mini-Batch Cost = 1.5153
# Epoch 971: Last Mini-Batch Cost = 2.8918
# Epoch 972: Last Mini-Batch Cost = 0.8272
# Epoch 973: Last Mini-Batch Cost = 2.7746
# Epoch 974: Last Mini-Batch Cost = 1.6752
# Epoch 975: Last Mini-Batch Cost = 2.0483
# Epoch 976: Last Mini-Batch Cost = 2.1657
# Epoch 977: Last Mini-Batch Cost = 1.8245
# Epoch 978: Last Mini-Batch Cost = 2.9013
# Epoch 979: Last Mini-Batch Cost = 1.4453
# Epoch 980: Last Mini-Batch Cost = 1.5921
# Epoch 981: Last Mini-Batch Cost = 1.5893
# Epoch 982: Last Mini-Batch Cost = 1.0090
# Epoch 983: Last Mini-Batch Cost = 0.9217
# Epoch 984: Last Mini-Batch Cost = 2.3910
# Epoch 985: Last Mini-Batch Cost = 3.0281
# Epoch 986: Last Mini-Batch Cost = 3.6037
# Epoch 987: Last Mini-Batch Cost = 2.3074
# Epoch 988: Last Mini-Batch Cost = 2.6202
# Epoch 989: Last Mini-Batch Cost = 1.4343
# Epoch 990: Last Mini-Batch Cost = 0.8104
# Epoch 991: Last Mini-Batch Cost = 1.7002
# Epoch 992: Last Mini-Batch Cost = 1.8773
# Epoch 993: Last Mini-Batch Cost = 1.4146
# Epoch 994: Last Mini-Batch Cost = 1.5969
# Epoch 995: Last Mini-Batch Cost = 3.3259
# Epoch 996: Last Mini-Batch Cost = 1.4110
# Epoch 997: Last Mini-Batch Cost = 1.1885
# Epoch 998: Last Mini-Batch Cost = 0.9064
# Epoch 999: Last Mini-Batch Cost = 1.6077
# Epoch 1000: Last Mini-Batch Cost = 1.3665
# Epoch 1001: Last Mini-Batch Cost = 3.1459
# Epoch 1002: Last Mini-Batch Cost = 1.1865
# Epoch 1003: Last Mini-Batch Cost = 3.2205
# Epoch 1004: Last Mini-Batch Cost = 2.9794
# Epoch 1005: Last Mini-Batch Cost = 2.9763
# Epoch 1006: Last Mini-Batch Cost = 1.2833
# Epoch 1007: Last Mini-Batch Cost = 3.1253
# Epoch 1008: Last Mini-Batch Cost = 2.2011
# Epoch 1009: Last Mini-Batch Cost = 1.6775
# Epoch 1010: Last Mini-Batch Cost = 2.9369
# Epoch 1011: Last Mini-Batch Cost = 1.7221
# Epoch 1012: Last Mini-Batch Cost = 1.0405
# Epoch 1013: Last Mini-Batch Cost = 1.6569
# Epoch 1014: Last Mini-Batch Cost = 1.9366
# Epoch 1015: Last Mini-Batch Cost = 1.2276
# Epoch 1016: Last Mini-Batch Cost = 1.0374
# Epoch 1017: Last Mini-Batch Cost = 1.3329
# Epoch 1018: Last Mini-Batch Cost = 0.7948
# Epoch 1019: Last Mini-Batch Cost = 1.3397
# Epoch 1020: Last Mini-Batch Cost = 2.0491
# Epoch 1021: Last Mini-Batch Cost = 0.9164
# Epoch 1022: Last Mini-Batch Cost = 3.0978
# Epoch 1023: Last Mini-Batch Cost = 1.3745
# Epoch 1024: Last Mini-Batch Cost = 1.4314
# Epoch 1025: Last Mini-Batch Cost = 3.6321
# Epoch 1026: Last Mini-Batch Cost = 1.6606
# Epoch 1027: Last Mini-Batch Cost = 1.2772
# Epoch 1028: Last Mini-Batch Cost = 1.3079
# Epoch 1029: Last Mini-Batch Cost = 1.7518
# Epoch 1030: Last Mini-Batch Cost = 1.1866
# Epoch 1031: Last Mini-Batch Cost = 3.3572
# Epoch 1032: Last Mini-Batch Cost = 1.7571
# Epoch 1033: Last Mini-Batch Cost = 1.7025
# Epoch 1034: Last Mini-Batch Cost = 1.0172
# Epoch 1035: Last Mini-Batch Cost = 1.4266
# Epoch 1036: Last Mini-Batch Cost = 1.8769
# Epoch 1037: Last Mini-Batch Cost = 2.1810
# Epoch 1038: Last Mini-Batch Cost = 1.3520
# Epoch 1039: Last Mini-Batch Cost = 1.6221
# Epoch 1040: Last Mini-Batch Cost = 1.3718
# Epoch 1041: Last Mini-Batch Cost = 1.1143
# Epoch 1042: Last Mini-Batch Cost = 1.1484
# Epoch 1043: Last Mini-Batch Cost = 1.0977
# Epoch 1044: Last Mini-Batch Cost = 1.6989
# Epoch 1045: Last Mini-Batch Cost = 1.7736
# Epoch 1046: Last Mini-Batch Cost = 3.2064
# Epoch 1047: Last Mini-Batch Cost = 1.8618
# Epoch 1048: Last Mini-Batch Cost = 1.2746
# Epoch 1049: Last Mini-Batch Cost = 1.0350
# Epoch 1050: Last Mini-Batch Cost = 1.5655
# Epoch 1051: Last Mini-Batch Cost = 1.7309
# Epoch 1052: Last Mini-Batch Cost = 1.3659
# Epoch 1053: Last Mini-Batch Cost = 1.2279
# Epoch 1054: Last Mini-Batch Cost = 2.3199
# Epoch 1055: Last Mini-Batch Cost = 3.0400
# Epoch 1056: Last Mini-Batch Cost = 2.2907
# Epoch 1057: Last Mini-Batch Cost = 1.8368
# Epoch 1058: Last Mini-Batch Cost = 1.9448
# Epoch 1059: Last Mini-Batch Cost = 3.5233
# Epoch 1060: Last Mini-Batch Cost = 1.7391
# Epoch 1061: Last Mini-Batch Cost = 1.1342
# Epoch 1062: Last Mini-Batch Cost = 2.7659
# Epoch 1063: Last Mini-Batch Cost = 1.4406
# Epoch 1064: Last Mini-Batch Cost = 0.9451
# Epoch 1065: Last Mini-Batch Cost = 2.1142
# Epoch 1066: Last Mini-Batch Cost = 1.9371
# Epoch 1067: Last Mini-Batch Cost = 3.3907
# Epoch 1068: Last Mini-Batch Cost = 1.1256
# Epoch 1069: Last Mini-Batch Cost = 1.1024
# Epoch 1070: Last Mini-Batch Cost = 2.6593
# Epoch 1071: Last Mini-Batch Cost = 1.6674
# Epoch 1072: Last Mini-Batch Cost = 1.4813
# Epoch 1073: Last Mini-Batch Cost = 3.1632
# Epoch 1074: Last Mini-Batch Cost = 1.5177
# Epoch 1075: Last Mini-Batch Cost = 1.8342
# Epoch 1076: Last Mini-Batch Cost = 1.7538
# Epoch 1077: Last Mini-Batch Cost = 1.2625
# Epoch 1078: Last Mini-Batch Cost = 3.7286
# Epoch 1079: Last Mini-Batch Cost = 1.6851
# Epoch 1080: Last Mini-Batch Cost = 1.6353
# Epoch 1081: Last Mini-Batch Cost = 1.9890
# Epoch 1082: Last Mini-Batch Cost = 2.8671
# Epoch 1083: Last Mini-Batch Cost = 2.8677
# Epoch 1084: Last Mini-Batch Cost = 2.1680
# Epoch 1085: Last Mini-Batch Cost = 3.3624
# Epoch 1086: Last Mini-Batch Cost = 1.5442
# Epoch 1087: Last Mini-Batch Cost = 1.6292
# Epoch 1088: Last Mini-Batch Cost = 1.8034
# Epoch 1089: Last Mini-Batch Cost = 2.1488
# Epoch 1090: Last Mini-Batch Cost = 2.2625
# Epoch 1091: Last Mini-Batch Cost = 1.5935
# Epoch 1092: Last Mini-Batch Cost = 2.7860
# Epoch 1093: Last Mini-Batch Cost = 3.2219
# Epoch 1094: Last Mini-Batch Cost = 1.4142
# Epoch 1095: Last Mini-Batch Cost = 1.8099
# Epoch 1096: Last Mini-Batch Cost = 1.7829
# Epoch 1097: Last Mini-Batch Cost = 3.2916
# Epoch 1098: Last Mini-Batch Cost = 1.2860
# Epoch 1099: Last Mini-Batch Cost = 1.1952
# Epoch 1100: Last Mini-Batch Cost = 2.6649
# Epoch 1101: Last Mini-Batch Cost = 0.9987
# Epoch 1102: Last Mini-Batch Cost = 1.7439
# Epoch 1103: Last Mini-Batch Cost = 1.6105
# Epoch 1104: Last Mini-Batch Cost = 1.5406
# Epoch 1105: Last Mini-Batch Cost = 2.9576
# Epoch 1106: Last Mini-Batch Cost = 1.7513
# Epoch 1107: Last Mini-Batch Cost = 1.9021
# Epoch 1108: Last Mini-Batch Cost = 1.5203
# Epoch 1109: Last Mini-Batch Cost = 1.9538
# Epoch 1110: Last Mini-Batch Cost = 1.2506
# Epoch 1111: Last Mini-Batch Cost = 2.6286
# Epoch 1112: Last Mini-Batch Cost = 1.9045
# Epoch 1113: Last Mini-Batch Cost = 1.3340
# Epoch 1114: Last Mini-Batch Cost = 1.2398
# Epoch 1115: Last Mini-Batch Cost = 1.2330
# Epoch 1116: Last Mini-Batch Cost = 1.8686
# Epoch 1117: Last Mini-Batch Cost = 1.7352
# Epoch 1118: Last Mini-Batch Cost = 1.6296
# Epoch 1119: Last Mini-Batch Cost = 1.5124
# Epoch 1120: Last Mini-Batch Cost = 1.0904
# Epoch 1121: Last Mini-Batch Cost = 1.1563
# Epoch 1122: Last Mini-Batch Cost = 1.7425
# Epoch 1123: Last Mini-Batch Cost = 1.7546
# Epoch 1124: Last Mini-Batch Cost = 1.2577
# Epoch 1125: Last Mini-Batch Cost = 1.3330
# Epoch 1126: Last Mini-Batch Cost = 1.5555
# Epoch 1127: Last Mini-Batch Cost = 1.3418
# Epoch 1128: Last Mini-Batch Cost = 1.4239
# Epoch 1129: Last Mini-Batch Cost = 2.4074
# Epoch 1130: Last Mini-Batch Cost = 1.5551
# Epoch 1131: Last Mini-Batch Cost = 1.4773
# Epoch 1132: Last Mini-Batch Cost = 1.9175
# Epoch 1133: Last Mini-Batch Cost = 1.6628
# Epoch 1134: Last Mini-Batch Cost = 2.7664
# Epoch 1135: Last Mini-Batch Cost = 2.8649
# Epoch 1136: Last Mini-Batch Cost = 1.3386
# Epoch 1137: Last Mini-Batch Cost = 1.4190
# Epoch 1138: Last Mini-Batch Cost = 1.2920
# Epoch 1139: Last Mini-Batch Cost = 1.9515
# Epoch 1140: Last Mini-Batch Cost = 1.4031
# Epoch 1141: Last Mini-Batch Cost = 1.7255
# Epoch 1142: Last Mini-Batch Cost = 1.8497
# Epoch 1143: Last Mini-Batch Cost = 3.2565
# Epoch 1144: Last Mini-Batch Cost = 1.3990
# Epoch 1145: Last Mini-Batch Cost = 1.7093
# Epoch 1146: Last Mini-Batch Cost = 1.8844
# Epoch 1147: Last Mini-Batch Cost = 2.4844
# Epoch 1148: Last Mini-Batch Cost = 1.2187
# Epoch 1149: Last Mini-Batch Cost = 1.6349
# Epoch 1150: Last Mini-Batch Cost = 1.7941
# Epoch 1151: Last Mini-Batch Cost = 2.6672
# Epoch 1152: Last Mini-Batch Cost = 1.2343
# Epoch 1153: Last Mini-Batch Cost = 0.9913
# Epoch 1154: Last Mini-Batch Cost = 3.2090
# Epoch 1155: Last Mini-Batch Cost = 3.7414
# Epoch 1156: Last Mini-Batch Cost = 0.8990
# Epoch 1157: Last Mini-Batch Cost = 3.0300
# Epoch 1158: Last Mini-Batch Cost = 2.8500
# Epoch 1159: Last Mini-Batch Cost = 3.2765
# Epoch 1160: Last Mini-Batch Cost = 3.0873
# Epoch 1161: Last Mini-Batch Cost = 1.1885
# Epoch 1162: Last Mini-Batch Cost = 2.3825
# Epoch 1163: Last Mini-Batch Cost = 1.2695
# Epoch 1164: Last Mini-Batch Cost = 0.8832
# Epoch 1165: Last Mini-Batch Cost = 0.9893
# Epoch 1166: Last Mini-Batch Cost = 1.8385
# Epoch 1167: Last Mini-Batch Cost = 1.6901
# Epoch 1168: Last Mini-Batch Cost = 2.7481
# ...
# Epoch 1621: Last Mini-Batch Cost = 1.5834
# Epoch 1622: Last Mini-Batch Cost = 1.8608
# Epoch 1623: Last Mini-Batch Cost = 1.2248
# Epoch 1624: Last Mini-Batch Cost = 1.3464
# Epoch 1625: Last Mini-Batch Cost = 1.1824
# Epoch 1626: Last Mini-Batch Cost = 1.3509
# Epoch 1627: Last Mini-Batch Cost = 2.1664
# Epoch 1628: Last Mini-Batch Cost = 0.9395
# Epoch 1629: Last Mini-Batch Cost = 1.3446
# Epoch 1630: Last Mini-Batch Cost = 1.5792
# Epoch 1631: Last Mini-Batch Cost = 3.1633
# Epoch 1632: Last Mini-Batch Cost = 1.3083
# Epoch 1633: Last Mini-Batch Cost = 3.3320
# Epoch 1634: Last Mini-Batch Cost = 1.2071
# Epoch 1635: Last Mini-Batch Cost = 1.9138
# Epoch 1636: Last Mini-Batch Cost = 2.6408
# Epoch 1637: Last Mini-Batch Cost = 1.4871
# Epoch 1638: Last Mini-Batch Cost = 3.3676
# Epoch 1639: Last Mini-Batch Cost = 0.6948
# Epoch 1640: Last Mini-Batch Cost = 2.0729
# Epoch 1641: Last Mini-Batch Cost = 1.0036
# Epoch 1642: Last Mini-Batch Cost = 1.2556
# Epoch 1643: Last Mini-Batch Cost = 0.9478
# Epoch 1644: Last Mini-Batch Cost = 1.5442
# Epoch 1645: Last Mini-Batch Cost = 2.1966
# Epoch 1646: Last Mini-Batch Cost = 2.5821
# Epoch 1647: Last Mini-Batch Cost = 1.2726
# Epoch 1648: Last Mini-Batch Cost = 1.7939
# Epoch 1649: Last Mini-Batch Cost = 1.3665
# Epoch 1650: Last Mini-Batch Cost = 1.0254
# Epoch 1651: Last Mini-Batch Cost = 3.0272
# Epoch 1652: Last Mini-Batch Cost = 0.7408
# Epoch 1653: Last Mini-Batch Cost = 1.3223
# Epoch 1654: Last Mini-Batch Cost = 1.5591
# Epoch 1655: Last Mini-Batch Cost = 1.5560
# Epoch 1656: Last Mini-Batch Cost = 2.0255
# Epoch 1657: Last Mini-Batch Cost = 0.9362
# Epoch 1658: Last Mini-Batch Cost = 1.7613
# Epoch 1659: Last Mini-Batch Cost = 2.0293
# Epoch 1660: Last Mini-Batch Cost = 1.2951
# Epoch 1661: Last Mini-Batch Cost = 1.5476
# Epoch 1662: Last Mini-Batch Cost = 1.4513
# Epoch 1663: Last Mini-Batch Cost = 1.5475
# Epoch 1664: Last Mini-Batch Cost = 1.3951
# Epoch 1665: Last Mini-Batch Cost = 1.0487
# Epoch 1666: Last Mini-Batch Cost = 0.9561
# Epoch 1667: Last Mini-Batch Cost = 1.9780
# Epoch 1668: Last Mini-Batch Cost = 0.8319
# Epoch 1669: Last Mini-Batch Cost = 1.2587
# Epoch 1670: Last Mini-Batch Cost = 1.1726
# Epoch 1671: Last Mini-Batch Cost = 1.1153
# Epoch 1672: Last Mini-Batch Cost = 1.2039
# Epoch 1673: Last Mini-Batch Cost = 3.5914
# Epoch 1674: Last Mini-Batch Cost = 1.9419
# Epoch 1675: Last Mini-Batch Cost = 1.4334
# Epoch 1676: Last Mini-Batch Cost = 1.3058
# Epoch 1677: Last Mini-Batch Cost = 3.1296
# Epoch 1678: Last Mini-Batch Cost = 3.2288
# Epoch 1679: Last Mini-Batch Cost = 3.1790
# Epoch 1680: Last Mini-Batch Cost = 1.2235
# Epoch 1681: Last Mini-Batch Cost = 1.6220
# Epoch 1682: Last Mini-Batch Cost = 2.6473
# Epoch 1683: Last Mini-Batch Cost = 1.2252
# Epoch 1684: Last Mini-Batch Cost = 1.4173
# Epoch 1685: Last Mini-Batch Cost = 0.9812
# Epoch 1686: Last Mini-Batch Cost = 1.2456
# Epoch 1687: Last Mini-Batch Cost = 1.3311
# Epoch 1688: Last Mini-Batch Cost = 1.6465
# Epoch 1689: Last Mini-Batch Cost = 1.1932
# Epoch 1690: Last Mini-Batch Cost = 1.5003
# Epoch 1691: Last Mini-Batch Cost = 1.0588
# Epoch 1692: Last Mini-Batch Cost = 1.7023
# Epoch 1693: Last Mini-Batch Cost = 1.8793
# Epoch 1694: Last Mini-Batch Cost = 2.6313
# Epoch 1695: Last Mini-Batch Cost = 1.4014
# Epoch 1696: Last Mini-Batch Cost = 1.2687
# Epoch 1697: Last Mini-Batch Cost = 2.8411
# Epoch 1698: Last Mini-Batch Cost = 1.9287
# Epoch 1699: Last Mini-Batch Cost = 2.0530
# Epoch 1700: Last Mini-Batch Cost = 1.9836
# Epoch 1701: Last Mini-Batch Cost = 2.1173
# Epoch 1702: Last Mini-Batch Cost = 1.5800
# Epoch 1703: Last Mini-Batch Cost = 1.3257
# Epoch 1704: Last Mini-Batch Cost = 1.9403
# Epoch 1705: Last Mini-Batch Cost = 1.8684
# Epoch 1706: Last Mini-Batch Cost = 1.5476
# Epoch 1707: Last Mini-Batch Cost = 0.9318
# Epoch 1708: Last Mini-Batch Cost = 1.9904
# Epoch 1709: Last Mini-Batch Cost = 1.0708
# Epoch 1710: Last Mini-Batch Cost = 1.2788
# Epoch 1711: Last Mini-Batch Cost = 1.4481
# Epoch 1712: Last Mini-Batch Cost = 1.0953
# Epoch 1713: Last Mini-Batch Cost = 1.6490
# Epoch 1714: Last Mini-Batch Cost = 1.0843
# Epoch 1715: Last Mini-Batch Cost = 1.3395
# Epoch 1716: Last Mini-Batch Cost = 1.1337
# Epoch 1717: Last Mini-Batch Cost = 1.9287
# Epoch 1718: Last Mini-Batch Cost = 2.0498
# Epoch 1719: Last Mini-Batch Cost = 1.3982
# Epoch 1720: Last Mini-Batch Cost = 1.2989
# Epoch 1721: Last Mini-Batch Cost = 2.8472
# Epoch 1722: Last Mini-Batch Cost = 1.1424
# Epoch 1723: Last Mini-Batch Cost = 1.4268
# Epoch 1724: Last Mini-Batch Cost = 1.6654
# Epoch 1725: Last Mini-Batch Cost = 2.5383
# Epoch 1726: Last Mini-Batch Cost = 1.2256
# Epoch 1727: Last Mini-Batch Cost = 3.4433
# Epoch 1728: Last Mini-Batch Cost = 2.2909
# Epoch 1729: Last Mini-Batch Cost = 2.3271
# Epoch 1730: Last Mini-Batch Cost = 1.2293
# Epoch 1731: Last Mini-Batch Cost = 1.6098
# Epoch 1732: Last Mini-Batch Cost = 1.2914
# Epoch 1733: Last Mini-Batch Cost = 1.3544
# Epoch 1734: Last Mini-Batch Cost = 1.5937
# Epoch 1735: Last Mini-Batch Cost = 2.5796
# Epoch 1736: Last Mini-Batch Cost = 3.0818
# Epoch 1737: Last Mini-Batch Cost = 1.6160
# Epoch 1738: Last Mini-Batch Cost = 1.6730
# Epoch 1739: Last Mini-Batch Cost = 0.9470
# Epoch 1740: Last Mini-Batch Cost = 1.1298
# Epoch 1741: Last Mini-Batch Cost = 1.6403
# Epoch 1742: Last Mini-Batch Cost = 2.0514
# Epoch 1743: Last Mini-Batch Cost = 3.0689
# Epoch 1744: Last Mini-Batch Cost = 3.1400
# Epoch 1745: Last Mini-Batch Cost = 1.3093
# Epoch 1746: Last Mini-Batch Cost = 1.2282
# Epoch 1747: Last Mini-Batch Cost = 1.4841
# Epoch 1748: Last Mini-Batch Cost = 1.6097
# Epoch 1749: Last Mini-Batch Cost = 2.3041
# Epoch 1750: Last Mini-Batch Cost = 1.4874
# Epoch 1751: Last Mini-Batch Cost = 1.2132
# Epoch 1752: Last Mini-Batch Cost = 1.4956
# Epoch 1753: Last Mini-Batch Cost = 0.9659
# Epoch 1754: Last Mini-Batch Cost = 1.2295
# Epoch 1755: Last Mini-Batch Cost = 1.5315
# Epoch 1756: Last Mini-Batch Cost = 2.7910
# Epoch 1757: Last Mini-Batch Cost = 1.6741
# Epoch 1758: Last Mini-Batch Cost = 1.1076
# Epoch 1759: Last Mini-Batch Cost = 1.2440
# Epoch 1760: Last Mini-Batch Cost = 1.7023
# Epoch 1761: Last Mini-Batch Cost = 1.7918
# Epoch 1762: Last Mini-Batch Cost = 1.3800
# Epoch 1763: Last Mini-Batch Cost = 1.7993
# Epoch 1764: Last Mini-Batch Cost = 2.2687
# Epoch 1765: Last Mini-Batch Cost = 0.9590
# Epoch 1766: Last Mini-Batch Cost = 1.7874
# Epoch 1767: Last Mini-Batch Cost = 3.2290
# Epoch 1768: Last Mini-Batch Cost = 2.2241
# Epoch 1769: Last Mini-Batch Cost = 1.7581
# Epoch 1770: Last Mini-Batch Cost = 2.7610
# Epoch 1771: Last Mini-Batch Cost = 1.9608
# Epoch 1772: Last Mini-Batch Cost = 1.9313
# Epoch 1773: Last Mini-Batch Cost = 2.0671
# Epoch 1774: Last Mini-Batch Cost = 1.5467
# Epoch 1775: Last Mini-Batch Cost = 1.1896
# Epoch 1776: Last Mini-Batch Cost = 1.5020
# Epoch 1777: Last Mini-Batch Cost = 1.3913
# Epoch 1778: Last Mini-Batch Cost = 1.7000
# Epoch 1779: Last Mini-Batch Cost = 3.4528
# Epoch 1780: Last Mini-Batch Cost = 2.1909
# Epoch 1781: Last Mini-Batch Cost = 1.5887
# Epoch 1782: Last Mini-Batch Cost = 1.4542
# Epoch 1783: Last Mini-Batch Cost = 3.0944
# Epoch 1784: Last Mini-Batch Cost = 3.7269
# Epoch 1785: Last Mini-Batch Cost = 1.8111
# Epoch 1786: Last Mini-Batch Cost = 1.0146
# Epoch 1787: Last Mini-Batch Cost = 1.5131
# Epoch 1788: Last Mini-Batch Cost = 1.4070
# Epoch 1789: Last Mini-Batch Cost = 1.8090
# Epoch 1790: Last Mini-Batch Cost = 1.4577
# Epoch 1791: Last Mini-Batch Cost = 1.4300
# Epoch 1792: Last Mini-Batch Cost = 3.0271
# Epoch 1793: Last Mini-Batch Cost = 1.0857
# Epoch 1794: Last Mini-Batch Cost = 1.0577
# Epoch 1795: Last Mini-Batch Cost = 1.5050
# Epoch 1796: Last Mini-Batch Cost = 0.8542
# Epoch 1797: Last Mini-Batch Cost = 1.2408
# Epoch 1798: Last Mini-Batch Cost = 2.4369
# Epoch 1799: Last Mini-Batch Cost = 1.3322
# Epoch 1800: Last Mini-Batch Cost = 1.9518
# Epoch 1801: Last Mini-Batch Cost = 1.4204
# Epoch 1802: Last Mini-Batch Cost = 2.6923
# Epoch 1803: Last Mini-Batch Cost = 2.6009
# Epoch 1804: Last Mini-Batch Cost = 1.7398
# Epoch 1805: Last Mini-Batch Cost = 1.3456
# Epoch 1806: Last Mini-Batch Cost = 1.8541
# Epoch 1807: Last Mini-Batch Cost = 1.5894
# Epoch 1808: Last Mini-Batch Cost = 1.9981
# Epoch 1809: Last Mini-Batch Cost = 3.0642
# Epoch 1810: Last Mini-Batch Cost = 1.1700
# Epoch 1811: Last Mini-Batch Cost = 2.5745
# Epoch 1812: Last Mini-Batch Cost = 3.0941
# Epoch 1813: Last Mini-Batch Cost = 1.3312
# Epoch 1814: Last Mini-Batch Cost = 2.1705
# Epoch 1815: Last Mini-Batch Cost = 2.9438
# Epoch 1816: Last Mini-Batch Cost = 3.5126
# Epoch 1817: Last Mini-Batch Cost = 1.9913
# Epoch 1818: Last Mini-Batch Cost = 1.6609
# Epoch 1819: Last Mini-Batch Cost = 2.4024
# Epoch 1820: Last Mini-Batch Cost = 0.8769
# Epoch 1821: Last Mini-Batch Cost = 1.6050
# Epoch 1822: Last Mini-Batch Cost = 1.7162
# Epoch 1823: Last Mini-Batch Cost = 1.1398
# Epoch 1824: Last Mini-Batch Cost = 1.3864
# Epoch 1825: Last Mini-Batch Cost = 0.9774
# Epoch 1826: Last Mini-Batch Cost = 2.5833
# Epoch 1827: Last Mini-Batch Cost = 2.7687
# Epoch 1828: Last Mini-Batch Cost = 1.4883
# Epoch 1829: Last Mini-Batch Cost = 1.1812
# Epoch 1830: Last Mini-Batch Cost = 3.5327
# Epoch 1831: Last Mini-Batch Cost = 2.1923
# Epoch 1832: Last Mini-Batch Cost = 1.9653
# Epoch 1833: Last Mini-Batch Cost = 1.6273
# Epoch 1834: Last Mini-Batch Cost = 1.5929
# Epoch 1835: Last Mini-Batch Cost = 2.1687
# Epoch 1836: Last Mini-Batch Cost = 1.3679
# Epoch 1837: Last Mini-Batch Cost = 2.9418
# Epoch 1838: Last Mini-Batch Cost = 1.5977
# Epoch 1839: Last Mini-Batch Cost = 0.8345
# Epoch 1840: Last Mini-Batch Cost = 0.9025
# Epoch 1841: Last Mini-Batch Cost = 2.6876
# Epoch 1842: Last Mini-Batch Cost = 2.0736
# Epoch 1843: Last Mini-Batch Cost = 1.0962
# Epoch 1844: Last Mini-Batch Cost = 1.3597
# Epoch 1845: Last Mini-Batch Cost = 1.8725
# Epoch 1846: Last Mini-Batch Cost = 1.8145
# Epoch 1847: Last Mini-Batch Cost = 1.0984
# Epoch 1848: Last Mini-Batch Cost = 1.5394
# Epoch 1849: Last Mini-Batch Cost = 2.3966
# Epoch 1850: Last Mini-Batch Cost = 1.0555
# Epoch 1851: Last Mini-Batch Cost = 2.1203
# Epoch 1852: Last Mini-Batch Cost = 1.1013
# Epoch 1853: Last Mini-Batch Cost = 2.6945
# Epoch 1854: Last Mini-Batch Cost = 1.1962
# Epoch 1855: Last Mini-Batch Cost = 1.2816
# Epoch 1856: Last Mini-Batch Cost = 1.1174
# Epoch 1857: Last Mini-Batch Cost = 1.3314
# Epoch 1858: Last Mini-Batch Cost = 2.9170
# Epoch 1859: Last Mini-Batch Cost = 2.0322
# Epoch 1860: Last Mini-Batch Cost = 1.1318
# Epoch 1861: Last Mini-Batch Cost = 2.8980
# Epoch 1862: Last Mini-Batch Cost = 1.2061
# Epoch 1863: Last Mini-Batch Cost = 2.2976
# Epoch 1864: Last Mini-Batch Cost = 2.7376
# Epoch 1865: Last Mini-Batch Cost = 0.7434
# Epoch 1866: Last Mini-Batch Cost = 0.8130
# Epoch 1867: Last Mini-Batch Cost = 2.0322
# Epoch 1868: Last Mini-Batch Cost = 1.3200
# Epoch 1869: Last Mini-Batch Cost = 1.3478
# Epoch 1870: Last Mini-Batch Cost = 1.5368
# Epoch 1871: Last Mini-Batch Cost = 1.7675
# Epoch 1872: Last Mini-Batch Cost = 2.1617
# Epoch 1873: Last Mini-Batch Cost = 0.9327
# Epoch 1874: Last Mini-Batch Cost = 3.0248
# Epoch 1875: Last Mini-Batch Cost = 1.6443
# Epoch 1876: Last Mini-Batch Cost = 1.0931
# Epoch 1877: Last Mini-Batch Cost = 1.9345
# Epoch 1878: Last Mini-Batch Cost = 1.5630
# Epoch 1879: Last Mini-Batch Cost = 2.7692
# Epoch 1880: Last Mini-Batch Cost = 2.5914
# Epoch 1881: Last Mini-Batch Cost = 1.6267
# Epoch 1882: Last Mini-Batch Cost = 1.5161
# Epoch 1883: Last Mini-Batch Cost = 0.9260
# Epoch 1884: Last Mini-Batch Cost = 1.5433
# Epoch 1885: Last Mini-Batch Cost = 3.5482
# Epoch 1886: Last Mini-Batch Cost = 1.4320
# Epoch 1887: Last Mini-Batch Cost = 1.1774
# Epoch 1888: Last Mini-Batch Cost = 3.0759
# Epoch 1889: Last Mini-Batch Cost = 1.1275
# Epoch 1890: Last Mini-Batch Cost = 1.8300
# Epoch 1891: Last Mini-Batch Cost = 1.6184
# Epoch 1892: Last Mini-Batch Cost = 1.4141
# Epoch 1893: Last Mini-Batch Cost = 1.0478
# Epoch 1894: Last Mini-Batch Cost = 1.6065
# Epoch 1895: Last Mini-Batch Cost = 1.3314
# Epoch 1896: Last Mini-Batch Cost = 1.8827
# Epoch 1897: Last Mini-Batch Cost = 1.9665
# Epoch 1898: Last Mini-Batch Cost = 1.7739
# Epoch 1899: Last Mini-Batch Cost = 1.8170
# Epoch 1900: Last Mini-Batch Cost = 1.1459
# Epoch 1901: Last Mini-Batch Cost = 1.1970
# Epoch 1902: Last Mini-Batch Cost = 1.6284
# Epoch 1903: Last Mini-Batch Cost = 1.3579
# Epoch 1904: Last Mini-Batch Cost = 2.4560
# Epoch 1905: Last Mini-Batch Cost = 1.5519
# Epoch 1906: Last Mini-Batch Cost = 1.2334
# Epoch 1907: Last Mini-Batch Cost = 1.4184
# Epoch 1908: Last Mini-Batch Cost = 1.8046
# Epoch 1909: Last Mini-Batch Cost = 1.1321
# Epoch 1910: Last Mini-Batch Cost = 1.6310
# Epoch 1911: Last Mini-Batch Cost = 1.3022
# Epoch 1912: Last Mini-Batch Cost = 1.4583
# Epoch 1913: Last Mini-Batch Cost = 1.9142
# Epoch 1914: Last Mini-Batch Cost = 1.3060
# Epoch 1915: Last Mini-Batch Cost = 2.1686
# Epoch 1916: Last Mini-Batch Cost = 1.8455
# Epoch 1917: Last Mini-Batch Cost = 1.7821
# Epoch 1918: Last Mini-Batch Cost = 1.8228
# Epoch 1919: Last Mini-Batch Cost = 2.5620
# Epoch 1920: Last Mini-Batch Cost = 1.2493
# Epoch 1921: Last Mini-Batch Cost = 2.6321
# Epoch 1922: Last Mini-Batch Cost = 1.8609
# Epoch 1923: Last Mini-Batch Cost = 2.7376
# Epoch 1924: Last Mini-Batch Cost = 1.8445
# Epoch 1925: Last Mini-Batch Cost = 1.6675
# Epoch 1926: Last Mini-Batch Cost = 1.3057
# Epoch 1927: Last Mini-Batch Cost = 1.6048
# Epoch 1928: Last Mini-Batch Cost = 1.5983
# Epoch 1929: Last Mini-Batch Cost = 1.2264
# Epoch 1930: Last Mini-Batch Cost = 3.1555
# Epoch 1931: Last Mini-Batch Cost = 1.3327
# Epoch 1932: Last Mini-Batch Cost = 2.0634
# Epoch 1933: Last Mini-Batch Cost = 4.0361
# Epoch 1934: Last Mini-Batch Cost = 0.8622
# Epoch 1935: Last Mini-Batch Cost = 3.7532
# Epoch 1936: Last Mini-Batch Cost = 1.1219
# Epoch 1937: Last Mini-Batch Cost = 2.7440
# Epoch 1938: Last Mini-Batch Cost = 2.4419
# Epoch 1939: Last Mini-Batch Cost = 0.7870
# Epoch 1940: Last Mini-Batch Cost = 1.4533
# Epoch 1941: Last Mini-Batch Cost = 2.5450
# Epoch 1942: Last Mini-Batch Cost = 1.4966
# Epoch 1943: Last Mini-Batch Cost = 1.6814
# Epoch 1944: Last Mini-Batch Cost = 2.6137
# Epoch 1945: Last Mini-Batch Cost = 2.6104
# Epoch 1946: Last Mini-Batch Cost = 1.4547
# Epoch 1947: Last Mini-Batch Cost = 1.1383
# Epoch 1948: Last Mini-Batch Cost = 1.3630
# Epoch 1949: Last Mini-Batch Cost = 3.0518
# Epoch 1950: Last Mini-Batch Cost = 3.7338
# Epoch 1951: Last Mini-Batch Cost = 1.7363
# Epoch 1952: Last Mini-Batch Cost = 2.9511
# Epoch 1953: Last Mini-Batch Cost = 2.4334
# Epoch 1954: Last Mini-Batch Cost = 1.4957
# Epoch 1955: Last Mini-Batch Cost = 3.8467
# Epoch 1956: Last Mini-Batch Cost = 1.7342
# Epoch 1957: Last Mini-Batch Cost = 1.1920
# Epoch 1958: Last Mini-Batch Cost = 1.1976
# Epoch 1959: Last Mini-Batch Cost = 3.0502
# Epoch 1960: Last Mini-Batch Cost = 2.8742
# Epoch 1961: Last Mini-Batch Cost = 1.6633
# Epoch 1962: Last Mini-Batch Cost = 1.4338
# Epoch 1963: Last Mini-Batch Cost = 1.3228
# Epoch 1964: Last Mini-Batch Cost = 2.8614
# Epoch 1965: Last Mini-Batch Cost = 1.8775
# Epoch 1966: Last Mini-Batch Cost = 1.0815
# Epoch 1967: Last Mini-Batch Cost = 1.9729
# Epoch 1968: Last Mini-Batch Cost = 2.0600
# Epoch 1969: Last Mini-Batch Cost = 3.2250
# Epoch 1970: Last Mini-Batch Cost = 1.6787
# Epoch 1971: Last Mini-Batch Cost = 2.7628
# Epoch 1972: Last Mini-Batch Cost = 1.2066
# Epoch 1973: Last Mini-Batch Cost = 1.3077
# Epoch 1974: Last Mini-Batch Cost = 1.5295
# Epoch 1975: Last Mini-Batch Cost = 1.3542
# Epoch 1976: Last Mini-Batch Cost = 1.9392
# Epoch 1977: Last Mini-Batch Cost = 1.1624
# Epoch 1978: Last Mini-Batch Cost = 1.4676
# Epoch 1979: Last Mini-Batch Cost = 1.9315
# Epoch 1980: Last Mini-Batch Cost = 1.8281
# Epoch 1981: Last Mini-Batch Cost = 2.0906
# Epoch 1982: Last Mini-Batch Cost = 2.1542
# Epoch 1983: Last Mini-Batch Cost = 1.9717
# Epoch 1984: Last Mini-Batch Cost = 1.1160
# Epoch 1985: Last Mini-Batch Cost = 2.7756
# Epoch 1986: Last Mini-Batch Cost = 1.7504
# Epoch 1987: Last Mini-Batch Cost = 1.1670
# Epoch 1988: Last Mini-Batch Cost = 2.2662
# Epoch 1989: Last Mini-Batch Cost = 1.9303
# Epoch 1990: Last Mini-Batch Cost = 3.5545
# Epoch 1991: Last Mini-Batch Cost = 2.0733
# Epoch 1992: Last Mini-Batch Cost = 2.1049
# Epoch 1993: Last Mini-Batch Cost = 3.3109
# Epoch 1994: Last Mini-Batch Cost = 1.7126
# Epoch 1995: Last Mini-Batch Cost = 2.9946
# Epoch 1996: Last Mini-Batch Cost = 2.0795
# Epoch 1997: Last Mini-Batch Cost = 2.4338
# Epoch 1998: Last Mini-Batch Cost = 1.5645
# Epoch 1999: Last Mini-Batch Cost = 1.3516
# Epoch 2000: Last Mini-Batch Cost = 1.2965

# %%
# Forward propagation on the test set using the best parameters
_, _, _, Y_test_pred = forward_propagation(
    best_W1_mb, best_W2_mb, best_b1_mb, best_b2_mb, X_test, Y_test
)

# Compute the cost on the test set
cost_test = cost_function(Y_test_pred, Y_test)

# Print the lowest Mean Squared Error (MSE) on the training set
print("MSE pada training dengan parameter terbaik:", best_cost)

# Print the Mean Squared Error (MSE) on the test set
print("MSE pada testing dengan parameter terbaik:", cost_test)
# Out:
# MSE pada training dengan parameter terbaik: 0.5646526531465363
# MSE pada testing dengan parameter terbaik: 1.2003932008488736

# %%
tv = float(input("What is your TV ad budget? "))
radio = float(input("What is your Radio ad budget? "))
newspaper = float(input("What is your Newspaper ad budget? "))

# group first via column
df_input = pd.DataFrame(
    {
        'TV Ad Budget ($)': [tv],
        'Radio Ad Budget ($)': [radio],
        'Newspaper Ad Budget ($)': [newspaper]
    }
)
print("\n")
print(df_input)

# scale the input
df_scaled = (df_input - mean) / std_dev
print("\n")
print(df_scaled)

# put into forward_propagation function
_, _, _, Y_test_pred = forward_propagation_final(
    best_W1_mb, best_W2_mb, best_b1_mb, best_b2_mb, df_scaled
)

# print result
print("\n")
print(Y_test_pred)
# Out:
# What is your TV ad budget?  28
# What is your Radio ad budget?  95
# What is your Newspaper ad budget?  37
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0              28.0                 95.0                     37.0
#
#
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0         -1.390045              4.84387                 0.296721
#
#
# [[25.03629908]]

# %% [markdown]
# ### Menggunakan metode Repeated K-Fold untuk membagi data menjadi training dan testing serta menerapkan teknik optimisasi Stochastic Gradient Descent (SGD)

# %%
# Dictionaries to store results
MSE_fold = {"training": [], "testing": []}
Weight_fold = {"W1": [], "W2": []}
bias_fold = {"b1": [], "b2": []}
index_fold = {"training": [], "testing": []}

# Target variable
Y = df[['Sales ($)']]

# Initialize RepeatedKFold
rkf = RepeatedKFold(n_splits=5, n_repeats=2, random_state=10)

# Loop through each fold
for fold, (train_index, test_index) in enumerate(rkf.split(X_scaled, Y)):
    X_train_fold, X_test_fold = X_scaled.loc[train_index], X_scaled.loc[test_index]
    Y_train_fold, Y_test_fold = Y.loc[train_index], Y.loc[test_index]
    
    # Get the number of features
    n = X_train_fold.shape[1]
    
    # Initialize parameters
    W1_SGD, W2_SGD, b1_SGD, b2_SGD = inisiasi_awal(n)
    
    if fold == 0:
        print(f"Jumlah sampel Train tiap fold      : {len(train_index)}")
        print(f"Jumlah sampel Test  tiap fold      : {len(test_index)}")  
        print(f"Jumlah atribut input               : {n}\n")

    print(f"Fold {fold + 1}:") 
    
    # Convert DataFrames to NumPy arrays
    X_train_fold = X_train_fold.to_numpy()
    Y_train_fold = Y_train_fold.to_numpy()

    # Train the model using SGD
    for epoch in range(300):
        for i in range(len(train_index)):
            X_i = X_train_fold[i].reshape(-1, 3)  # Reshape as needed
            Y_i = Y_train_fold[i].reshape(-1, 1)  # Reshape as needed
            
            # Forward propagation
            z1_SGD, A1_SGD, z2_SGD, Y_pred_SGD = forward_propagation(
                W1_SGD, W2_SGD, b1_SGD, b2_SGD, X_i, Y_i
            )
            
            # Compute cost
            cost_SGD = cost_function(Y_pred_SGD, Y_i)
            
            # Backward propagation
            dW1_SGD, dW2_SGD, db1_SGD, db2_SGD = back_propagation(
                X_i, W1_SGD, z1_SGD, A1_SGD, W2_SGD, z2_SGD, Y_pred_SGD, Y_i, len(train_index)
            )
            
            # Update parameters
            W1_SGD, W2_SGD, b1_SGD, b2_SGD = update_parameter(
                0.01, W1_SGD, W2_SGD, b1_SGD, b2_SGD, dW1_SGD, dW2_SGD, db1_SGD, db2_SGD
            )
    
    # Print training cost
    print("     cost pada training  :", cost_SGD)

    # Testing/Validation
    _, _, _, Y_test_pred = forward_propagation(
        W1_SGD, W2_SGD, b1_SGD, b2_SGD, X_test_fold, Y_test_fold
    )
    cost_test = cost_function(Y_test_pred, Y_test_fold)
    
    # Print testing cost
    print("     MSE pada testing    :", cost_test)

    # Save results
    index_fold['training'].append(np.squeeze(train_index).tolist())
    index_fold['testing'].append(np.squeeze(test_index).tolist())
    MSE_fold["training"].append(cost_SGD)
    MSE_fold['testing'].append(cost_test)
    Weight_fold['W1'].append(np.squeeze(W1_SGD).tolist())
    Weight_fold['W2'].append(np.squeeze(W2_SGD).tolist())
    bias_fold["b1"].append(b1_SGD)
    bias_fold["b2"].append(b2_SGD)
# Out:
# Jumlah sampel Train tiap fold      : 160
# Jumlah sampel Test  tiap fold      : 40
# Jumlah atribut input               : 3
#
# Fold 1:
#      cost pada training  : 1.1364137851516714
#      MSE pada testing    : 4.863639224058225
# Fold 2:
#      cost pada training  : 0.009664183819847712
#      MSE pada testing    : 1.0635067658405593
# Fold 3:
#      cost pada training  : 0.25663653260280855
#      MSE pada testing    : 1.2843319998066018
# Fold 4:
#      cost pada training  : 0.0953439867377515
#      MSE pada testing    : 1.4885833833759097
# Fold 5:
#      cost pada training  : 0.20300971286583916
#      MSE pada testing    : 1.2643605036926218
# Fold 6:
#      cost pada training  : 0.17682528257453173
#      MSE pada testing    : 1.4778875044315698
# Fold 7:
#      cost pada training  : 0.014402418845586427
#      MSE pada testing    : 2.0812203994908547
# Fold 8:
#      cost pada training  : 0.15555079432456415
#      MSE pada testing    : 1.5837504297715128
# Fold 9:
#      cost pada training  : 0.5200570690661555
#      MSE pada testing    : 1.9994547559084725
# Fold 10:
#      cost pada training  : 0.15765416251347558
#      MSE pada testing    : 1.8082943393283366

# %%
# Find the index of the fold with the smallest testing MSE
fold_terbaik = np.argmin(MSE_fold['testing'])
testing_index = index_fold['testing'][fold_terbaik]

# Retrieve the best weights and biases from the fold with the smallest testing MSE
best_W1_sgd = np.array(Weight_fold['W1'][fold_terbaik])
best_W2_sgd = np.array(Weight_fold['W2'][fold_terbaik])
best_b1_sgd = bias_fold['b1'][fold_terbaik]
best_b2_sgd = bias_fold['b2'][fold_terbaik]

# Perform forward propagation using the best weights and biases
_, _, _, Y_test_pred = forward_propagation(
    best_W1_sgd,
    best_W2_sgd,
    best_b1_sgd,
    best_b2_sgd,
    X_scaled.loc[testing_index],
    Y.loc[testing_index]
)

# Compute the MSE on the test data
cost_test = cost_function(Y_test_pred, Y.loc[testing_index])

# Print the fold number with the smallest testing MSE
print(f"MSE dari testing terkecil pada Fold ke-{fold_terbaik + 1}: {cost_test}")
# Out:
# MSE dari testing terkecil pada Fold ke-2: 1.0635067658405593

# %%
tv = float(input("What is your TV ad budget? "))
radio = float(input("What is your Radio ad budget? "))
newspaper = float(input("What is your Newspaper ad budget? "))

# group first via column
df_input = pd.DataFrame(
    {
        'TV Ad Budget ($)': [tv],
        'Radio Ad Budget ($)': [radio],
        'Newspaper Ad Budget ($)': [newspaper]
    }
)
print("\n")
print(df_input)

# scale the input
df_scaled = (df_input - mean) / std_dev
print("\n")
print(df_scaled)

# put into forward_propagation function
_, _, _, Y_test_pred = forward_propagation_final(
    best_W1_sgd, best_W2_sgd, best_b1_sgd, best_b2_sgd, df_scaled
)

# print result
print("\n")
print(Y_test_pred)
# Out:
# What is your TV ad budget?  93
# What is your Radio ad budget?  48
# What is your Newspaper ad budget?  12
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0              93.0                 48.0                     12.0
#
#
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0         -0.631048             1.670263                -0.854074
#
#
# [[16.14996653]]
